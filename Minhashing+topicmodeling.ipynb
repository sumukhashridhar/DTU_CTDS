# %% [markdown]
# # MinHashing  using  LSH package

# %%
import sys
import os
import mmh3
import numpy as np
import itertools
import collections
import argparse
import snapy
import pandas as pd
from datasketch import MinHash
from datasketch import MinHashLSH
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from tqdm import tqdm
import pandas as pd
import os
import csv
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import string
from nltk.stem.wordnet import WordNetLemmatizer
import re
from gensim.test.utils import common_corpus, common_dictionary
from gensim.models import LdaMulticore, LdaModel
import sys
import pandas as pd
import scipy as sc
import scipy.sparse as sparse
from sklearn.feature_extraction.text import CountVectorizer
from gensim import matutils as genmath
from gensim import corpora, models
import gensim

# %%
#import the document of stopwords 
stop = set(stopwords.words('english'))

# %%
#import our dataset and then put them into the dataframe 
data = pd.read_csv("E:\\plagiarism_detection\\articles1.csv", sep=',')
data_content = data["content"] #we are only interested in the content in each news

# %%
def clean(text):
    """
    This function takes as input a text on which several 
    NLTK algorithms will be applied in order to preprocess it
    """
  
    tokens = word_tokenize(text)
    # Remove the punctuations
    tokens = [word for word in tokens if word not in stop and len(word) > 2]
    # Lower the tokens
    tokens = [word.lower() for word in tokens]
    # Remove stopword
    tokens = [word for word in tokens if not word in stop]
   
    return tokens

# %%
docs1={}
for i in data_content.index:  
    cleaned = clean(data_content[i])   
    docs1[i] = str([' '.join(cleaned)])

# %%
def hashed_lst_shingles(q, doc):
    
    doc = doc.split(" ")
    lst_shingles=[]

    lst_shingles = [doc[i:i+q] for i in range(0, len(doc), q-2)] # create list of shingles of length q

    lst_shingles = [x for x in lst_shingles if len(x)==q] # remove shingles with length < q

    return lst_shingles

# %%
docs_clean = {}
count = 1
for i,k in docs1.items():
  docs_clean["m{0}".format(count)] = hashed_lst_shingles(3,k)
  count +=1

# %%
docs_clean['m3']
# Out:
# [["['walt", 'disney', 'bambi'],
#  ['disney', 'bambi', 'opened'],
#  ['bambi', 'opened', '1942'],
#  ['opened', '1942', 'critics'],
#  ['1942', 'critics', 'praised'],
#  ['critics', 'praised', 'spare'],
#  ['praised', 'spare', 'haunting'],
#  ['spare', 'haunting', 'visual'],
#  ['haunting', 'visual', 'style'],
#  ['visual', 'style', 'vastly'],
#  ['style', 'vastly', 'different'],
#  ['vastly', 'different', 'anything'],
#  ['different', 'anything', 'disney'],
#  ['anything', 'disney', 'done'],
#  ['disney', 'done', 'know'],
#  ['done', 'know', 'film'],
#  ['know', 'film', 'striking'],
#  ['film', 'striking', 'appearance'],
#  ['striking', 'appearance', 'created'],
#  ['appearance', 'created', 'chinese'],
#  ['created', 'chinese', 'immigrant'],
#  ['chinese', 'immigrant', 'artist'],
#  ['immigrant', 'artist', 'took'],
#  ['artist', 'took', 'inspiration'],
#  ['took', 'inspiration', 'landscape'],
#  ['inspiration', 'landscape', 'paintings'],
#  ['landscape', 'paintings', 'song'],
#  ['paintings', 'song', 'dynasty'],
#  ['song', 'dynasty', 'extent'],
#  ['dynasty', 'extent', 'contribution'],
#  ['extent', 'contribution', 'bambi'],
#  ['contribution', 'bambi', 'remains'],
#  ['bambi', 'remains', 'mark'],
#  ['remains', 'mark', 'film'],
#  ['mark', 'film', 'animation'],
#  ['film', 'animation', 'would'],
#  ['animation', 'would', 'widely'],
#  ['would', 'widely', 'known'],
#  ['widely', 'known', 'decades'],
#  ['known', 'decades', 'like'],
#  ['decades', 'like', 'film'],
#  ['like', 'film', 'title'],
#  ['film', 'title', 'character'],
#  ['title', 'character', 'artist'],
#  ['character', 'artist', 'tyrus'],
#  ['artist', 'tyrus', 'wong'],
#  ['tyrus', 'wong', 'weathered'],
#  ['wong', 'weathered', 'irrevocable'],
#  ['weathered', 'irrevocable', 'separation'],
#  ['irrevocable', 'separation', 'mother'],
#  ['separation', 'mother', 'hope'],
#  ['mother', 'hope', 'making'],
#  ['hope', 'making', 'life'],
#  ['making', 'life', 'america'],
#  ['life', 'america', 'incarceration'],
#  ['america', 'incarceration', 'isolation'],
#  ['incarceration', 'isolation', 'rigorous'],
#  ['isolation', 'rigorous', 'interrogation'],
#  ['rigorous', 'interrogation', 'still'],
#  ['interrogation', 'still', 'child'],
#  ['still', 'child', 'years'],
#  ['child', 'years', 'followed'],
#  ['years', 'followed', 'endured'],
#  ['followed', 'endured', 'poverty'],
#  ['endured', 'poverty', 'discrimination'],
#  ['poverty', 'discrimination', 'chronic'],
#  ['discrimination', 'chronic', 'lack'],
#  ['chronic', 'lack', 'recognition'],
#  ['lack', 'recognition', 'work'],
#  ['recognition', 'work', 'disney'],
#  ['work', 'disney', 'also'],
#  ['disney', 'also', 'fine'],
#  ['also', 'fine', 'art'],
#  ['fine', 'art', 'finding'],
#  ['art', 'finding', 'acclaim'],
#  ['finding', 'acclaim', '90s'],
#  ['acclaim', '90s', 'mr.'],
#  ['90s', 'mr.', 'wong'],
#  ['mr.', 'wong', 'died'],
#  ['wong', 'died', 'friday'],
#  ['died', 'friday', '106'],
#  ['friday', '106', 'hollywood'],
#  ['106', 'hollywood', 'studio'],
#  ['hollywood', 'studio', 'artist'],
#  ['studio', 'artist', 'painter'],
#  ['artist', 'painter', 'printmaker'],
#  ['painter', 'printmaker', 'calligrapher'],
#  ['printmaker', 'calligrapher', 'illustrator'],
#  ['calligrapher', 'illustrator', 'later'],
#  ['illustrator', 'later', 'years'],
#  ['later', 'years', 'maker'],
#  ['years', 'maker', 'fantastical'],
#  ['maker', 'fantastical', 'kites'],
#  ['fantastical', 'kites', 'one'],
#  ['kites', 'one', 'celebrated'],
#  ['one', 'celebrated', 'artists'],
#  ['celebrated', 'artists', '20th'],
#  ['artists', '20th', 'century'],
#  ['20th', 'century', 'marginalization'],
#  ['century', 'marginalization', 'long'],
#  ['marginalization', 'long', 'subject'],
#  ['long', 'subject', 'passed'],
#  ['subject', 'passed', 'much'],
#  ['passed', 'much', 'career'],
#  ['much', 'career', 'unknown'],
#  ['career', 'unknown', 'general'],
#  ['unknown', 'general', 'public'],
#  ['general', 'public', 'artistic'],
#  ['public', 'artistic', 'recognition'],
#  ['artistic', 'recognition', 'mr.'],
#  ['recognition', 'mr.', 'wong'],
#  ['mr.', 'wong', 'find'],
#  ['wong', 'find', 'noteworthy'],
#  ['find', 'noteworthy', 'fact'],
#  ['noteworthy', 'fact', 'among'],
#  ['fact', 'among', 'chinese'],
#  ['among', 'chinese', 'immigrant'],
#  ['chinese', 'immigrant', 'men'],
#  ['immigrant', 'men', 'generation'],
#  ['men', 'generation', 'professional'],
#  ['generation', 'professional', 'prospects'],
#  ['professional', 'prospects', 'largely'],
#  ['prospects', 'largely', 'limited'],
#  ['largely', 'limited', 'menial'],
#  ['limited', 'menial', 'jobs'],
#  ['menial', 'jobs', 'like'],
#  ['jobs', 'like', 'houseboy'],
#  ['like', 'houseboy', 'laundryman'],
#  ['houseboy', 'laundryman', 'trained'],
#  ['laundryman', 'trained', 'painter'],
#  ['trained', 'painter', 'mr.'],
#  ['painter', 'mr.', 'wong'],
#  ['mr.', 'wong', 'leading'],
#  ['wong', 'leading', 'figure'],
#  ['leading', 'figure', 'modernist'],
#  ['figure', 'modernist', 'movement'],
#  ['modernist', 'movement', 'flourished'],
#  ['movement', 'flourished', 'california'],
#  ['flourished', 'california', 'first'],
#  ['california', 'first', 'second'],
#  ['first', 'second', 'world'],
#  ['second', 'world', 'wars'],
#  ['world', 'wars', '1932'],
#  ['wars', '1932', '1934'],
#  ['1932', '1934', 'work'],
#  ['1934', 'work', 'included'],
#  ['work', 'included', 'group'],
#  ['included', 'group', 'shows'],
#  ['group', 'shows', 'art'],
#  ['shows', 'art', 'institute'],
#  ['art', 'institute', 'chicago'],
#  ['institute', 'chicago', 'also'],
#  ['chicago', 'also', 'featured'],
#  ['also', 'featured', 'picasso'],
#  ['featured', 'picasso', 'matisse'],
#  ['picasso', 'matisse', 'paul'],
#  ['matisse', 'paul', 'klee'],
#  ['paul', 'klee', 'staff'],
#  ['klee', 'staff', 'artist'],
#  ['staff', 'artist', 'hollywood'],
#  ['artist', 'hollywood', 'studios'],
#  ['hollywood', 'studios', '1930s'],
#  ['studios', '1930s', '1960s'],
#  ['1930s', '1960s', 'drew'],
#  ['1960s', 'drew', 'storyboards'],
#  ['drew', 'storyboards', 'made'],
#  ['storyboards', 'made', 'vibrant'],
#  ['made', 'vibrant', 'paintings'],
#  ['vibrant', 'paintings', 'detailed'],
#  ['paintings', 'detailed', 'architectural'],
#  ['detailed', 'architectural', 'illustrations'],
#  ['architectural', 'illustrations', 'helped'],
#  ['illustrations', 'helped', 'director'],
#  ['helped', 'director', 'envision'],
#  ['director', 'envision', 'scene'],
#  ['envision', 'scene', 'shot'],
#  ['scene', 'shot', 'years'],
#  ['shot', 'years', 'work'],
#  ['years', 'work', 'informed'],
#  ['work', 'informed', 'look'],
#  ['informed', 'look', 'animated'],
#  ['look', 'animated', 'pictures'],
#  ['animated', 'pictures', 'disney'],
#  ['pictures', 'disney', 'films'],
#  ['disney', 'films', 'warner'],
#  ['films', 'warner', 'brothers'],
#  ['warner', 'brothers', 'studios'],
#  ['brothers', 'studios', 'among'],
#  ['studios', 'among', 'sands'],
#  ['among', 'sands', 'iwo'],
#  ['sands', 'iwo', 'jima'],
#  ['iwo', 'jima', '1949'],
#  ['jima', '1949', 'rebel'],
#  ['1949', 'rebel', 'without'],
#  ['rebel', 'without', 'cause'],
#  ['without', 'cause', '1955'],
#  ['cause', '1955', 'wild'],
#  ['1955', 'wild', 'bunch'],
#  ['wild', 'bunch', '1969'],
#  ['bunch', '1969', 'dozens'],
#  ['1969', 'dozens', 'films'],
#  ['dozens', 'films', 'worked'],
#  ['films', 'worked', 'bambi'],
#  ['worked', 'bambi', 'mr.'],
#  ['bambi', 'mr.', 'wong'],
#  ['mr.', 'wong', 'belatedly'],
#  ['wong', 'belatedly', 'renowned'],
#  ['belatedly', 'renowned', 'truly'],
#  ['renowned', 'truly', 'involved'],
#  ['truly', 'involved', 'every'],
#  ['involved', 'every', 'phase'],
#  ['every', 'phase', 'production'],
#  ['phase', 'production', 'john'],
#  ['production', 'john', 'canemaker'],
#  ['john', 'canemaker', 'animator'],
#  ['canemaker', 'animator', 'historian'],
#  ['animator', 'historian', 'animation'],
#  ['historian', 'animation', 'new'],
#  ['animation', 'new', 'york'],
#  ['new', 'york', 'university'],
#  ['york', 'university', 'said'],
#  ['university', 'said', 'interview'],
#  ['said', 'interview', 'obituary'],
#  ['interview', 'obituary', 'march'],
#  ['obituary', 'march', 'created'],
#  ['march', 'created', 'art'],
#  ['created', 'art', 'direction'],
#  ['art', 'direction', 'really'],
#  ['direction', 'really', 'never'],
#  ['really', 'never', 'seen'],
#  ['never', 'seen', 'animation'],
#  ['seen', 'animation', '2013'],
#  ['animation', '2013', '2014'],
#  ['2013', '2014', 'mr.'],
#  ['2014', 'mr.', 'wong'],
#  ['mr.', 'wong', 'subject'],
#  ['wong', 'subject', 'water'],
#  ['subject', 'water', 'paper'],
#  ['water', 'paper', 'paint'],
#  ['paper', 'paint', 'sky'],
#  ['paint', 'sky', 'major'],
#  ['sky', 'major', 'retrospective'],
#  ['major', 'retrospective', 'disney'],
#  ['retrospective', 'disney', 'family'],
#  ['disney', 'family', 'museum'],
#  ['family', 'museum', 'san'],
#  ['museum', 'san', 'francisco'],
#  ['san', 'francisco', 'museum'],
#  ['francisco', 'museum', 'windows'],
#  ['museum', 'windows', 'overlook'],
#  ['windows', 'overlook', 'san'],
#  ['overlook', 'san', 'francisco'],
#  ['san', 'francisco', 'bay'],
#  ['francisco', 'bay', 'could'],
#  ['bay', 'could', 'contemplate'],
#  ['could', 'contemplate', 'angel'],
#  ['contemplate', 'angel', 'island'],
#  ['angel', 'island', 'nine'],
#  ['island', 'nine', 'decades'],
#  ['nine', 'decades', 'earlier'],
#  ['decades', 'earlier', 'lone'],
#  ['earlier', 'lone', 'sought'],
#  ['lone', 'sought', 'gain'],
#  ['sought', 'gain', 'admission'],
#  ['gain', 'admission', 'country'],
#  ['admission', 'country', 'adamantly'],
#  ['country', 'adamantly', 'want'],
#  ['adamantly', 'want', 'wong'],
#  ['want', 'wong', 'gen'],
#  ['wong', 'gen', 'yeo'],
#  ['gen', 'yeo', 'name'],
#  ['yeo', 'name', 'sometimes'],
#  ['name', 'sometimes', 'romanized'],
#  ['sometimes', 'romanized', 'wong'],
#  ['romanized', 'wong', 'gaing'],
#  ['wong', 'gaing', 'yoo'],
#  ['gaing', 'yoo', 'born'],
#  ['yoo', 'born', 'oct.'],
#  ['born', 'oct.', '1910'],
#  ['oct.', '1910', 'farming'],
#  ['1910', 'farming', 'village'],
#  ['farming', 'village', 'guangdong'],
#  ['village', 'guangdong', 'province'],
#  ['guangdong', 'province', 'young'],
#  ['province', 'young', 'child'],
#  ['young', 'child', 'already'],
#  ['child', 'already', 'exhibited'],
#  ['already', 'exhibited', 'love'],
#  ['exhibited', 'love', 'drawing'],
#  ['love', 'drawing', 'encouraged'],
#  ['drawing', 'encouraged', 'father'],
#  ['encouraged', 'father', '1920'],
#  ['father', '1920', 'seeking'],
#  ['1920', 'seeking', 'better'],
#  ['seeking', 'better', 'economic'],
#  ['better', 'economic', 'prospects'],
#  ['economic', 'prospects', 'gen'],
#  ['prospects', 'gen', 'yeo'],
#  ['gen', 'yeo', 'father'],
#  ['yeo', 'father', 'embarked'],
#  ['father', 'embarked', 'united'],
#  ['embarked', 'united', 'states'],
#  ['united', 'states', 'leaving'],
#  ['states', 'leaving', 'mother'],
#  ['leaving', 'mother', 'sister'],
#  ['mother', 'sister', 'behind'],
#  ['sister', 'behind', 'gen'],
#  ['behind', 'gen', 'yeo'],
#  ['gen', 'yeo', 'would'],
#  ['yeo', 'would', 'never'],
#  ['would', 'never', 'see'],
#  ['never', 'see', 'mother'],
#  ['see', 'mother', 'obliged'],
#  ['mother', 'obliged', 'travel'],
#  ['obliged', 'travel', 'false'],
#  ['travel', 'false', 'identities'],
#  ['false', 'identities', 'state'],
#  ['identities', 'state', 'affairs'],
#  ['state', 'affairs', 'known'],
#  ['affairs', 'known', 'among'],
#  ['known', 'among', 'chinese'],
#  ['among', 'chinese', 'immigrants'],
#  ['chinese', 'immigrants', 'paper'],
#  ['immigrants', 'paper', 'son'],
#  ['paper', 'son', 'hope'],
#  ['son', 'hope', 'circumventing'],
#  ['hope', 'circumventing', 'chinese'],
#  ['circumventing', 'chinese', 'exclusion'],
#  ['chinese', 'exclusion', 'act'],
#  ['exclusion', 'act', '1882'],
#  ['act', '1882', 'signed'],
#  ['1882', 'signed', 'law'],
#  ['signed', 'law', 'president'],
#  ['law', 'president', 'chester'],
#  ['president', 'chester', 'arthur'],
#  ['chester', 'arthur', 'act'],
#  ['arthur', 'act', 'drastically'],
#  ['act', 'drastically', 'curtailed'],
#  ['drastically', 'curtailed', 'number'],
#  ['curtailed', 'number', 'chinese'],
#  ['number', 'chinese', 'people'],
#  ['chinese', 'people', 'allowed'],
#  ['people', 'allowed', 'enter'],
#  ['allowed', 'enter', 'country'],
#  ['enter', 'country', 'among'],
#  ['country', 'among', 'earliest'],
#  ['among', 'earliest', 'united'],
#  ['earliest', 'united', 'states'],
#  ['united', 'states', 'laws'],
#  ['states', 'laws', 'impose'],
#  ['laws', 'impose', 'severe'],
#  ['impose', 'severe', 'restrictions'],
#  ['severe', 'restrictions', 'immigration'],
#  ['restrictions', 'immigration', '1906'],
#  ['immigration', '1906', 'unforeseen'],
#  ['1906', 'unforeseen', 'loophole'],
#  ['unforeseen', 'loophole', 'opened'],
#  ['loophole', 'opened', 'form'],
#  ['opened', 'form', 'san'],
#  ['form', 'san', 'francisco'],
#  ['san', 'francisco', 'earthquake'],
#  ['francisco', 'earthquake', 'fire'],
#  ['earthquake', 'fire', 'huge'],
#  ['fire', 'huge', 'number'],
#  ['huge', 'number', 'municipal'],
#  ['number', 'municipal', 'documents'],
#  ['municipal', 'documents', 'including'],
#  ['documents', 'including', 'birth'],
#  ['including', 'birth', 'immigration'],
#  ['birth', 'immigration', 'records'],
#  ['immigration', 'records', 'destroyed'],
#  ['records', 'destroyed', 'many'],
#  ['destroyed', 'many', 'newly'],
#  ['many', 'newly', 'arrived'],
#  ['newly', 'arrived', 'chinese'],
#  ['arrived', 'chinese', 'capitalized'],
#  ['chinese', 'capitalized', 'loss'],
#  ['capitalized', 'loss', 'maintaining'],
#  ['loss', 'maintaining', 'born'],
#  ['maintaining', 'born', 'san'],
#  ['born', 'san', 'francisco'],
#  ['san', 'francisco', 'fire'],
#  ['francisco', 'fire', 'united'],
#  ['fire', 'united', 'states'],
#  ['united', 'states', 'citizens'],
#  ['states', 'citizens', 'entitled'],
#  ['citizens', 'entitled', 'bring'],
#  ['entitled', 'bring', 'relatives'],
#  ['bring', 'relatives', 'case'],
#  ['relatives', 'case', 'gen'],
#  ['case', 'gen', 'yeo'],
#  ['gen', 'yeo', 'father'],
#  ['yeo', 'father', 'paper'],
#  ['father', 'paper', 'sons'],
#  ['paper', 'sons', 'posing'],
#  ['sons', 'posing', 'relatives'],
#  ['posing', 'relatives', 'attuned'],
#  ['relatives', 'attuned', 'deception'],
#  ['attuned', 'deception', 'united'],
#  ['deception', 'united', 'states'],
#  ['united', 'states', 'immigration'],
#  ['states', 'immigration', 'officials'],
#  ['immigration', 'officials', 'put'],
#  ['officials', 'put', 'chinese'],
#  ['put', 'chinese', 'arrivals'],
#  ['chinese', 'arrivals', 'formidable'],
#  ['arrivals', 'formidable', 'inquisition'],
#  ['formidable', 'inquisition', 'ensure'],
#  ['inquisition', 'ensure', 'claimed'],
#  ['ensure', 'claimed', 'questions'],
#  ['claimed', 'questions', 'came'],
#  ['questions', 'came', 'like'],
#  ['came', 'like', 'gunfire'],
#  ['like', 'gunfire', 'direction'],
#  ['gunfire', 'direction', 'village'],
#  ['direction', 'village', 'face'],
#  ['village', 'face', 'many'],
#  ['face', 'many', 'windows'],
#  ['many', 'windows', 'house'],
#  ['windows', 'house', 'house'],
#  ['house', 'house', 'rice'],
#  ['house', 'rice', 'bin'],
#  ['rice', 'bin', 'wide'],
#  ['bin', 'wide', 'well'],
#  ['wide', 'well', 'deep'],
#  ['well', 'deep', 'trees'],
#  ['deep', 'trees', 'village'],
#  ['trees', 'village', 'lakes'],
#  ['village', 'lakes', 'shops'],
#  ['lakes', 'shops', 'name'],
#  ['shops', 'name', 'sponsoring'],
#  ['name', 'sponsoring', 'relative'],
#  ['sponsoring', 'relative', 'interrogated'],
#  ['relative', 'interrogated', 'separately'],
#  ['interrogated', 'separately', 'answers'],
#  ['separately', 'answers', 'match'],
#  ['answers', 'match', 'new'],
#  ['match', 'new', 'arrival'],
#  ['new', 'arrival', 'major'],
#  ['arrival', 'major', 'mistake'],
#  ['major', 'mistake', 'series'],
#  ['mistake', 'series', 'smaller'],
#  ['series', 'smaller', 'ones'],
#  ['smaller', 'ones', 'could'],
#  ['ones', 'could', 'mean'],
#  ['could', 'mean', 'deportation'],
#  ['mean', 'deportation', 'stand'],
#  ['deportation', 'stand', 'chance'],
#  ['stand', 'chance', 'passing'],
#  ['chance', 'passing', 'aspirants'],
#  ['passing', 'aspirants', 'memorized'],
#  ['aspirants', 'memorized', 'rigorous'],
#  ['memorized', 'rigorous', 'dossiers'],
#  ['rigorous', 'dossiers', 'known'],
#  ['dossiers', 'known', 'coaching'],
#  ['known', 'coaching', 'papers'],
#  ['coaching', 'papers', 'ensuing'],
#  ['papers', 'ensuing', 'interrogation'],
#  ['ensuing', 'interrogation', 'hard'],
#  ['interrogation', 'hard', 'enough'],
#  ['hard', 'enough', 'adults'],
#  ['enough', 'adults', 'gen'],
#  ['adults', 'gen', 'yeo'],
#  ['gen', 'yeo', 'would'],
#  ['yeo', 'would', 'undergo'],
#  ['would', 'undergo', 'alone'],
#  ['undergo', 'alone', 'dec.'],
#  ['alone', 'dec.', '1920'],
#  ['dec.', '1920', 'month'],
#  ['1920', 'month', 'sea'],
#  ['month', 'sea', 'wongs'],
#  ['sea', 'wongs', 'landed'],
#  ['wongs', 'landed', 'angel'],
#  ['landed', 'angel', 'island'],
#  ['angel', 'island', 'immigration'],
#  ['island', 'immigration', 'station'],
#  ['immigration', 'station', 'elder'],
#  ['station', 'elder', 'mr.'],
#  ['elder', 'mr.', 'wong'],
#  ['mr.', 'wong', 'traveling'],
#  ['wong', 'traveling', 'merchant'],
#  ['traveling', 'merchant', 'named'],
#  ['merchant', 'named', 'look'],
#  ['named', 'look', 'get'],
#  ['look', 'get', 'son'],
#  ['get', 'son', 'look'],
#  ['son', 'look', 'tai'],
#  ['look', 'tai', 'yow'],
#  ['tai', 'yow', 'angel'],
#  ['yow', 'angel', 'island'],
#  ['angel', 'island', 'considered'],
#  ['island', 'considered', 'ellis'],
#  ['considered', 'ellis', 'island'],
#  ['ellis', 'island', 'west'],
#  ['island', 'west', 'coast'],
#  ['west', 'coast', 'lisa'],
#  ['coast', 'lisa', 'see'],
#  ['lisa', 'see', 'author'],
#  ['see', 'author', 'gold'],
#  ['author', 'gold', 'mountain'],
#  ['gold', 'mountain', '1995'],
#  ['mountain', '1995', 'nonfiction'],
#  ['1995', 'nonfiction', 'chronicle'],
#  ['nonfiction', 'chronicle', 'family'],
#  ['chronicle', 'family', 'said'],
#  ['family', 'said', 'interview'],
#  ['said', 'interview', '2016'],
#  ['interview', '2016', 'however'],
#  ['2016', 'however', 'continued'],
#  ['however', 'continued', 'goal'],
#  ['continued', 'goal', 'really'],
#  ['goal', 'really', 'different'],
#  ['really', 'different', 'ellis'],
#  ['different', 'ellis', 'island'],
#  ['ellis', 'island', 'supposed'],
#  ['island', 'supposed', 'welcoming'],
#  ['supposed', 'welcoming', 'angel'],
#  ['welcoming', 'angel', 'island'],
#  ['angel', 'island', 'opened'],
#  ['island', 'opened', 'specifically'],
#  ['opened', 'specifically', 'keep'],
#  ['specifically', 'keep', 'chinese'],
#  ['keep', 'chinese', 'mr.'],
#  ['chinese', 'mr.', 'wong'],
#  ['mr.', 'wong', 'father'],
#  ['wong', 'father', 'previously'],
#  ['father', 'previously', 'lived'],
#  ['previously', 'lived', 'united'],
#  ['lived', 'united', 'states'],
#  ['united', 'states', 'look'],
#  ['states', 'look', 'get'],
#  ['look', 'get', 'able'],
#  ['get', 'able', 'clear'],
#  ['able', 'clear', 'immigration'],
#  ['clear', 'immigration', 'quickly'],
#  ['immigration', 'quickly', 'new'],
#  ['quickly', 'new', 'arrival'],
#  ['new', 'arrival', 'gen'],
#  ['arrival', 'gen', 'yeo'],
#  ['gen', 'yeo', 'detained'],
#  ['yeo', 'detained', 'island'],
#  ['detained', 'island', 'nearly'],
#  ['island', 'nearly', 'month'],
#  ['nearly', 'month', 'child'],
#  ['month', 'child', 'among'],
#  ['child', 'among', 'immigrants'],
#  ['among', 'immigrants', 'held'],
#  ['immigrants', 'held', 'scared'],
#  ['held', 'scared', 'half'],
#  ['scared', 'half', 'death'],
#  ['half', 'death', 'cried'],
#  ['death', 'cried', 'mr.'],
#  ['cried', 'mr.', 'wong'],
#  ['mr.', 'wong', 'recalled'],
#  ['wong', 'recalled', 'tyrus'],
#  ['recalled', 'tyrus', 'documentary'],
#  ['tyrus', 'documentary', 'directed'],
#  ['documentary', 'directed', 'pamela'],
#  ['directed', 'pamela', 'tom'],
#  ['pamela', 'tom', 'premiered'],
#  ['tom', 'premiered', '2015'],
#  ['premiered', '2015', 'every'],
#  ['2015', 'every', 'day'],
#  ['every', 'day', 'miserable'],
#  ['day', 'miserable', 'miserable'],
#  ['miserable', 'miserable', 'hated'],
#  ['miserable', 'hated', 'place'],
#  ['hated', 'place', 'jan.'],
#  ['place', 'jan.', '1921'],
#  ['jan.', '1921', 'presence'],
#  ['1921', 'presence', 'interpreter'],
#  ['presence', 'interpreter', 'stenographer'],
#  ['interpreter', 'stenographer', 'young'],
#  ['stenographer', 'young', 'gen'],
#  ['young', 'gen', 'yeo'],
#  ['gen', 'yeo', 'posing'],
#  ['yeo', 'posing', 'look'],
#  ['posing', 'look', 'tai'],
#  ['look', 'tai', 'yow'],
#  ['tai', 'yow', 'interrogated'],
#  ['yow', 'interrogated', 'three'],
#  ['interrogated', 'three', 'inspectors'],
#  ['three', 'inspectors', 'father'],
#  ['inspectors', 'father', 'already'],
#  ['father', 'already', 'questioned'],
#  ['already', 'questioned', 'gen'],
#  ['questioned', 'gen', 'yeo'],
#  ['gen', 'yeo', 'well'],
#  ['yeo', 'well', 'prepared'],
#  ['well', 'prepared', 'answered'],
#  ['prepared', 'answered', 'without'],
#  ['answered', 'without', 'error'],
#  ['without', 'error', 'sacramento'],
#  ['error', 'sacramento', 'joined'],
#  ['sacramento', 'joined', 'father'],
#  ['joined', 'father', 'schoolteacher'],
#  ['father', 'schoolteacher', 'americanized'],
#  ['schoolteacher', 'americanized', 'tai'],
#  ['americanized', 'tai', 'yow'],
#  ['tai', 'yow', 'tyrus'],
#  ['yow', 'tyrus', 'known'],
#  ['tyrus', 'known', 'tyrus'],
#  ['known', 'tyrus', 'wong'],
#  ['tyrus', 'wong', 'ever'],
#  ['wong', 'ever', 'soon'],
#  ['ever', 'soon', 'afterward'],
#  ['soon', 'afterward', 'father'],
#  ['afterward', 'father', 'son'],
#  ['father', 'son', 'separated'],
#  ['son', 'separated', 'elder'],
#  ['separated', 'elder', 'mr.'],
#  ['elder', 'mr.', 'wong'],
#  ['mr.', 'wong', 'moved'],
#  ['wong', 'moved', 'los'],
#  ['moved', 'los', 'angeles'],
#  ['los', 'angeles', 'seek'],
#  ['angeles', 'seek', 'work'],
#  ['seek', 'work', 'reasons'],
#  ['work', 'reasons', 'lost'],
#  ['reasons', 'lost', 'time'],
#  ['lost', 'time', 'could'],
#  ['time', 'could', 'take'],
#  ['could', 'take', 'son'],
#  ['take', 'son', 'tyrus'],
#  ['son', 'tyrus', 'lived'],
#  ['tyrus', 'lived', 'sacramento'],
#  ['lived', 'sacramento', 'boardinghouse'],
#  ['sacramento', 'boardinghouse', 'attending'],
#  ['boardinghouse', 'attending', 'elementary'],
#  ['attending', 'elementary', 'school'],
#  ['elementary', 'school', 'two'],
#  ['school', 'two', 'years'],
#  ['two', 'years', 'later'],
#  ['years', 'later', 'possibly'],
#  ['later', 'possibly', 'tyrus'],
#  ['possibly', 'tyrus', 'traveled'],
#  ['tyrus', 'traveled', 'los'],
#  ['traveled', 'los', 'angeles'],
#  ['los', 'angeles', 'join'],
#  ['angeles', 'join', 'father'],
#  ['join', 'father', 'found'],
#  ['father', 'found', 'work'],
#  ['found', 'work', 'gambling'],
#  ['work', 'gambling', 'den'],
#  ['gambling', 'den', 'lived'],
#  ['den', 'lived', 'boardinghouse'],
#  ['lived', 'boardinghouse', 'sandwiched'],
#  ['boardinghouse', 'sandwiched', 'butcher'],
#  ['sandwiched', 'butcher', 'shop'],
#  ['butcher', 'shop', 'brothel'],
#  ['shop', 'brothel', 'school'],
#  ['brothel', 'school', 'tyrus'],
#  ['school', 'tyrus', 'worked'],
#  ['tyrus', 'worked', 'houseboy'],
#  ['worked', 'houseboy', 'two'],
#  ['houseboy', 'two', 'pasadena'],
#  ['two', 'pasadena', 'families'],
#  ['pasadena', 'families', 'earning'],
#  ['families', 'earning', 'cents'],
#  ['earning', 'cents', 'day'],
#  ['cents', 'day', 'first'],
#  ['day', 'first', 'art'],
#  ['first', 'art', 'teacher'],
#  ['art', 'teacher', 'father'],
#  ['teacher', 'father', 'trained'],
#  ['father', 'trained', 'nightly'],
#  ['trained', 'nightly', 'calligraphy'],
#  ['nightly', 'calligraphy', 'dip'],
#  ['calligraphy', 'dip', 'brush'],
#  ['dip', 'brush', 'water'],
#  ['brush', 'water', 'trace'],
#  ['water', 'trace', 'ghostly'],
#  ['trace', 'ghostly', 'characters'],
#  ['ghostly', 'characters', 'newspaper'],
#  ['characters', 'newspaper', 'could'],
#  ['newspaper', 'could', 'afford'],
#  ['could', 'afford', 'ink'],
#  ['afford', 'ink', 'drawing'],
#  ['ink', 'drawing', 'paper'],
#  ['drawing', 'paper', 'tyrus'],
#  ['paper', 'tyrus', 'junior'],
#  ['tyrus', 'junior', 'high'],
#  ['junior', 'high', 'teacher'],
#  ['high', 'teacher', 'noting'],
#  ['teacher', 'noting', 'drawing'],
#  ['noting', 'drawing', 'talent'],
#  ['drawing', 'talent', 'arranged'],
#  ['talent', 'arranged', 'summer'],
#  ['arranged', 'summer', 'scholarship'],
#  ['summer', 'scholarship', 'otis'],
#  ['scholarship', 'otis', 'art'],
#  ['otis', 'art', 'institute'],
#  ['art', 'institute', 'los'],
#  ['institute', 'los', 'angeles'],
#  ['los', 'angeles', 'account'],
#  ['angeles', 'account', 'indifferent'],
#  ['account', 'indifferent', 'student'],
#  ['indifferent', 'student', 'public'],
#  ['student', 'public', 'school'],
#  ['public', 'school', 'tyrus'],
#  ['school', 'tyrus', 'found'],
#  ['tyrus', 'found', 'calling'],
#  ['found', 'calling', 'institute'],
#  ['calling', 'institute', 'otis'],
#  ['institute', 'otis', 'college'],
#  ['otis', 'college', 'art'],
#  ['college', 'art', 'design'],
#  ['art', 'design', 'scholarship'],
#  ['design', 'scholarship', 'ended'],
#  ['scholarship', 'ended', 'declined'],
#  ['ended', 'declined', 'return'],
#  ['declined', 'return', 'junior'],
#  ['return', 'junior', 'high'],
#  ['junior', 'high', 'father'],
#  ['high', 'father', 'scraped'],
#  ['father', 'scraped', 'together'],
#  ['scraped', 'together', 'tuition'],
#  ['together', 'tuition', 'small'],
#  ['tuition', 'small', 'fortune'],
#  ['small', 'fortune', 'let'],
#  ['fortune', 'let', 'stay'],
#  ['let', 'stay', 'otis'],
#  ['stay', 'otis', 'youngest'],
#  ['otis', 'youngest', 'student'],
#  ['youngest', 'student', 'studied'],
#  ['student', 'studied', 'least'],
#  ['studied', 'least', 'five'],
#  ['least', 'five', 'years'],
#  ['five', 'years', 'simultaneously'],
#  ['years', 'simultaneously', 'working'],
#  ['simultaneously', 'working', 'school'],
#  ['working', 'school', 'janitor'],
#  ['school', 'janitor', 'graduating'],
#  ['janitor', 'graduating', '1930s'],
#  ['graduating', '1930s', 'long'],
#  ['1930s', 'long', 'afterward'],
#  ['long', 'afterward', 'father'],
#  ['afterward', 'father', 'died'],
#  ['father', 'died', 'leaving'],
#  ['died', 'leaving', 'young'],
#  ['leaving', 'young', 'mr.'],
#  ['young', 'mr.', 'wong'],
#  ['mr.', 'wong', 'entirely'],
#  ['wong', 'entirely', '1936'],
#  ['entirely', '1936', '1938'],
#  ['1936', '1938', 'mr.'],
#  ['1938', 'mr.', 'wong'],
#  ['mr.', 'wong', 'artist'],
#  ['wong', 'artist', 'works'],
#  ['artist', 'works', 'progress'],
#  ['works', 'progress', 'administration'],
#  ['progress', 'administration', 'creating'],
#  ['administration', 'creating', 'paintings'],
#  ['creating', 'paintings', 'libraries'],
#  ['paintings', 'libraries', 'public'],
#  ['libraries', 'public', 'spaces'],
#  ['public', 'spaces', 'friends'],
#  ['spaces', 'friends', 'including'],
#  ['friends', 'including', 'artist'],
#  ['including', 'artist', 'benji'],
#  ['artist', 'benji', 'okubo'],
#  ['benji', 'okubo', 'founded'],
#  ['okubo', 'founded', 'oriental'],
#  ['founded', 'oriental', 'artists'],
#  ['oriental', 'artists', 'group'],
#  ['artists', 'group', 'los'],
#  ['group', 'los', 'angeles'],
#  ['los', 'angeles', 'organized'],
#  ['angeles', 'organized', 'exhibitions'],
#  ['organized', 'exhibitions', 'members'],
#  ['exhibitions', 'members', 'work'],
#  ['members', 'work', 'level'],
#  ['work', 'level', 'exposure'],
#  ['level', 'exposure', 'asian'],
#  ['exposure', 'asian', 'artists'],
#  ['asian', 'artists', 'time'],
#  ['artists', 'time', 'mr.'],
#  ['time', 'mr.', 'wong'],
#  ['mr.', 'wong', 'newly'],
#  ['wong', 'newly', 'married'],
#  ['newly', 'married', 'needing'],
#  ['married', 'needing', 'steady'],
#  ['needing', 'steady', 'work'],
#  ['steady', 'work', 'joined'],
#  ['work', 'joined', 'disney'],
#  ['joined', 'disney', '1938'],
#  ['disney', '1938', 'creating'],
#  ['1938', 'creating', 'thousands'],
#  ['creating', 'thousands', 'intermediate'],
#  ['thousands', 'intermediate', 'drawings'],
#  ['intermediate', 'drawings', 'bring'],
#  ['drawings', 'bring', 'animated'],
#  ['bring', 'animated', 'sequences'],
#  ['animated', 'sequences', 'life'],
#  ['sequences', 'life', 'asians'],
#  ['life', 'asians', 'novelty'],
#  ['asians', 'novelty', 'hollywood'],
#  ['novelty', 'hollywood', 'studios'],
#  ['hollywood', 'studios', 'mr.'],
#  ['studios', 'mr.', 'wong'],
#  ['mr.', 'wong', 'made'],
#  ['wong', 'made', 'keenly'],
#  ['made', 'keenly', 'aware'],
#  ['keenly', 'aware', 'fact'],
#  ['aware', 'fact', 'first'],
#  ['fact', 'first', 'disney'],
#  ['first', 'disney', 'later'],
#  ['disney', 'later', 'warner'],
#  ['later', 'warner', 'brothers'],
#  ['warner', 'brothers', 'one'],
#  ['brothers', 'one', 'flung'],
#  ['one', 'flung', 'racial'],
#  ['flung', 'racial', 'epithet'],
#  ['racial', 'epithet', 'another'],
#  ['epithet', 'another', 'assumed'],
#  ['another', 'assumed', 'sight'],
#  ['assumed', 'sight', 'worked'],
#  ['sight', 'worked', 'company'],
#  ['worked', 'company', 'cafeteria'],
#  ['company', 'cafeteria', 'affront'],
#  ['cafeteria', 'affront', 'job'],
#  ['affront', 'job', 'painstaking'],
#  ['job', 'painstaking', 'repetitive'],
#  ['painstaking', 'repetitive', 'mr.'],
#  ['repetitive', 'mr.', 'wong'],
#  ['mr.', 'wong', 'quickly'],
#  ['wong', 'quickly', 'work'],
#  ['quickly', 'work', 'animation'],
#  ['work', 'animation', 'terrible'],
#  ['animation', 'terrible', 'use'],
#  ['terrible', 'use', 'talents'],
#  ['use', 'talents', 'landscape'],
#  ['talents', 'landscape', 'artist'],
#  ['landscape', 'artist', 'painter'],
#  ['artist', 'painter', 'mr.'],
#  ['painter', 'mr.', 'canemaker'],
#  ['mr.', 'canemaker', 'said'],
#  ['canemaker', 'said', 'reprieve'],
#  ['said', 'reprieve', 'came'],
#  ['reprieve', 'came', 'late'],
#  ['came', 'late', '1930s'],
#  ['late', '1930s', 'mr.'],
#  ['1930s', 'mr.', 'wong'],
#  ['mr.', 'wong', 'learned'],
#  ['wong', 'learned', 'disney'],
#  ['learned', 'disney', 'adapting'],
#  ['disney', 'adapting', 'bambi'],
#  ['adapting', 'bambi', 'life'],
#  ['bambi', 'life', 'woods'],
#  ['life', 'woods', '1923'],
#  ['woods', '1923', 'novel'],
#  ['1923', 'novel', 'austrian'],
#  ['novel', 'austrian', 'writer'],
#  ['austrian', 'writer', 'felix'],
#  ['writer', 'felix', 'salten'],
#  ['felix', 'salten', 'fawn'],
#  ['salten', 'fawn', 'whose'],
#  ['fawn', 'whose', 'mother'],
#  ['whose', 'mother', 'killed'],
#  ['mother', 'killed', 'hunter'],
#  ['killed', 'hunter', 'trying'],
#  ['hunter', 'trying', 'animate'],
#  ['trying', 'animate', 'book'],
#  ['animate', 'book', 'disney'],
#  ['book', 'disney', 'reached'],
#  ['disney', 'reached', 'impasse'],
#  ['reached', 'impasse', 'studio'],
#  ['impasse', 'studio', 'enjoyed'],
#  ['studio', 'enjoyed', 'great'],
#  ['enjoyed', 'great', 'success'],
#  ['great', 'success', '1937'],
#  ['success', '1937', 'animated'],
#  ['1937', 'animated', 'film'],
#  ['animated', 'film', 'snow'],
#  ['film', 'snow', 'white'],
#  ['snow', 'white', 'seven'],
#  ['white', 'seven', 'dwarfs'],
#  ['seven', 'dwarfs', 'baroque'],
#  ['dwarfs', 'baroque', 'production'],
#  ['baroque', 'production', 'every'],
#  ['production', 'every', 'detail'],
#  ['every', 'detail', 'backgrounds'],
#  ['detail', 'backgrounds', 'every'],
#  ['backgrounds', 'every', 'petal'],
#  ['every', 'petal', 'every'],
#  ['petal', 'every', 'flower'],
#  ['every', 'flower', 'every'],
#  ['flower', 'every', 'leaf'],
#  ['every', 'leaf', 'every'],
#  ['leaf', 'every', 'tree'],
#  ['every', 'tree', 'meticulously'],
#  ['tree', 'meticulously', 'represented'],
#  ['meticulously', 'represented', 'attempt'],
#  ['represented', 'attempt', 'use'],
#  ['attempt', 'use', 'similar'],
#  ['use', 'similar', 'style'],
#  ['similar', 'style', 'bambi'],
#  ['style', 'bambi', 'found'],
#  ['bambi', 'found', 'ornate'],
#  ['found', 'ornate', 'backgrounds'],
#  ['ornate', 'backgrounds', 'camouflaged'],
#  ['backgrounds', 'camouflaged', 'deer'],
#  ['camouflaged', 'deer', 'forest'],
#  ['deer', 'forest', 'creatures'],
#  ['forest', 'creatures', 'narrative'],
#  ['creatures', 'narrative', 'centered'],
#  ['narrative', 'centered', 'mr.'],
#  ['centered', 'mr.', 'wong'],
#  ['mr.', 'wong', 'spied'],
#  ['wong', 'spied', 'chance'],
#  ['spied', 'chance', 'said'],
#  ['chance', 'said', 'gee'],
#  ['said', 'gee', 'outdoor'],
#  ['gee', 'outdoor', 'scenery'],
#  ['outdoor', 'scenery', 'recalled'],
#  ['scenery', 'recalled', 'video'],
#  ['recalled', 'video', 'interview'],
#  ['video', 'interview', 'years'],
#  ['interview', 'years', 'afterward'],
#  ['years', 'afterward', 'adding'],
#  ['afterward', 'adding', 'said'],
#  ['adding', 'said', 'gee'],
#  ['said', 'gee', 'landscape'],
#  ['gee', 'landscape', 'painter'],
#  ['landscape', 'painter', 'invoking'],
#  ['painter', 'invoking', 'exquisite'],
#  ['invoking', 'exquisite', 'landscape'],
#  ['exquisite', 'landscape', 'paintings'],
#  ['landscape', 'paintings', 'song'],
#  ['paintings', 'song', 'dynasty'],
#  ['song', 'dynasty', '960'],
#  ['dynasty', '960', '1279'],
#  ['960', '1279', 'rendered'],
#  ['1279', 'rendered', 'watercolors'],
#  ['rendered', 'watercolors', 'pastels'],
#  ['watercolors', 'pastels', 'series'],
#  ['pastels', 'series', 'nature'],
#  ['series', 'nature', 'scenes'],
#  ['nature', 'scenes', 'moody'],
#  ['scenes', 'moody', 'lyrical'],
#  ['moody', 'lyrical', 'atmospheric'],
#  ['lyrical', 'atmospheric', 'lush'],
#  ['atmospheric', 'lush', 'spare'],
#  ['lush', 'spare', 'backgrounds'],
#  ['spare', 'backgrounds', 'subtly'],
#  ['backgrounds', 'subtly', 'suggested'],
#  ['subtly', 'suggested', 'stroke'],
#  ['suggested', 'stroke', 'two'],
#  ['stroke', 'two', 'brush'],
#  ['two', 'brush', 'walt'],
#  ['brush', 'walt', 'disney'],
#  ['walt', 'disney', 'went'],
#  ['disney', 'went', 'crazy'],
#  ['went', 'crazy', 'said'],
#  ['crazy', 'said', 'mr.'],
#  ['said', 'mr.', 'canemaker'],
#  ['mr.', 'canemaker', 'wrote'],
#  ['canemaker', 'wrote', 'mr.'],
#  ['wrote', 'mr.', 'wong'],
#  ['mr.', 'wong', 'book'],
#  ['wong', 'book', 'animation'],
#  ['book', 'animation', 'begins'],
#  ['animation', 'begins', 'art'],
#  ['begins', 'art', 'lives'],
#  ['art', 'lives', 'disney'],
#  ['lives', 'disney', 'inspirational'],
#  ['disney', 'inspirational', 'sketch'],
#  ['inspirational', 'sketch', 'artists'],
#  ['sketch', 'artists', '1996'],
#  ['artists', '1996', 'said'],
#  ['1996', 'said', 'love'],
#  ['said', 'love', 'indefinite'],
#  ['love', 'indefinite', 'quality'],
#  ['indefinite', 'quality', 'mysterious'],
#  ['quality', 'mysterious', 'quality'],
#  ['mysterious', 'quality', 'forest'],
#  ['quality', 'forest', 'mr.'],
#  ['forest', 'mr.', 'wong'],
#  ['mr.', 'wong', 'unofficially'],
#  ['wong', 'unofficially', 'promoted'],
#  ['unofficially', 'promoted', 'rank'],
#  ['promoted', 'rank', 'inspirational'],
#  ['rank', 'inspirational', 'sketch'],
#  ['inspirational', 'sketch', 'artist'],
#  ['sketch', 'artist', 'mr.'],
#  ['artist', 'mr.', 'canemaker'],
#  ['mr.', 'canemaker', 'explained'],
#  ['canemaker', 'explained', 'designer'],
#  ['explained', 'designer', 'person'],
#  ['designer', 'person', 'went'],
#  ['person', 'went', 'questions'],
#  ['went', 'questions', 'color'],
#  ['questions', 'color', 'lay'],
#  ['color', 'lay', 'something'],
#  ['lay', 'something', 'even'],
#  ['something', 'even', 'influenced'],
#  ['even', 'influenced', 'music'],
#  ['influenced', 'music', 'special'],
#  ['music', 'special', 'effects'],
#  ['special', 'effects', 'look'],
#  ...]

# %%
num_perm = 100
min_dict1 = {}
count3 = 1
for val in tqdm(docs_clean.values()):
    m = MinHash(num_perm=num_perm)
    for shingle in val:    
      a= []
      for i in shingle:
        i.encode('utf8')
        a.append(i)
      data1 = str(['_'.join(a)])

      m.update(data1.encode('utf8'))
    min_dict1["m{}".format(count3)] = m
    count3+=1
# Out:
# 100%|██████████| 50000/50000 [05:24<00:00, 154.10it/s]

# %%
    
lsh = MinHashLSH(threshold=0.54, num_perm=num_perm)
for key in tqdm(min_dict1.keys()):
    lsh.insert(key,min_dict1[key]) # insert minhash data structure
# Out:
# 100%|██████████| 50000/50000 [00:03<00:00, 16122.40it/s]

# %%
def create_cand_pairs():
    big_list = []
    for query in min_dict1.keys():
        bucket = lsh.query(min_dict1[query])
        if len(bucket)==1:
            big_list.append([bucket[0],"None"])
        if len(bucket)>1:
            first_val = bucket[0]
            for val in bucket[1:]:
                second_val = val
                big_list.append([first_val,second_val])
    return big_list

# %%
pairs = create_cand_pairs()
pairs1 = [i for i in pairs if i[1] != 'None']

# %%
len(pairs1)
# Out:
# 16606

# %% [markdown]
#  We found that there are so many repetitive pairs so that we have to remove those repetitive pairs

# %%
pairs1
# Out:
# [['m4924', 'm134'],
#  ['m846', 'm813'],
#  ['m846', 'm813'],
#  ['m1163', 'm32722'],
#  ['m30978', 'm48358'],
#  ['m30978', 'm46590'],
#  ['m30978', 'm44583'],
#  ['m30978', 'm45640'],
#  ['m30978', 'm21870'],
#  ['m30978', 'm28835'],
#  ['m30978', 'm13010'],
#  ['m30978', 'm24822'],
#  ['m30978', 'm15722'],
#  ['m30978', 'm45731'],
#  ['m30978', 'm36295'],
#  ['m30978', 'm23669'],
#  ['m30978', 'm45404'],
#  ['m30978', 'm18373'],
#  ['m30978', 'm43299'],
#  ['m30978', 'm30321'],
#  ['m30978', 'm23999'],
#  ['m30978', 'm30611'],
#  ['m30978', 'm45740'],
#  ['m30978', 'm47616'],
#  ['m30978', 'm30001'],
#  ['m30978', 'm44835'],
#  ['m30978', 'm30937'],
#  ['m30978', 'm48523'],
#  ['m30978', 'm16724'],
#  ['m30978', 'm47986'],
#  ['m30978', 'm40127'],
#  ['m30978', 'm49631'],
#  ['m30978', 'm40096'],
#  ['m30978', 'm43102'],
#  ['m30978', 'm45538'],
#  ['m30978', 'm45610'],
#  ['m30978', 'm47949'],
#  ['m30978', 'm46860'],
#  ['m30978', 'm47792'],
#  ['m30978', 'm23228'],
#  ['m30978', 'm27873'],
#  ['m30978', 'm44515'],
#  ['m30978', 'm25722'],
#  ['m30978', 'm46110'],
#  ['m30978', 'm44929'],
#  ['m30978', 'm45456'],
#  ['m30978', 'm45946'],
#  ['m30978', 'm47492'],
#  ['m30978', 'm39870'],
#  ['m30978', 'm45696'],
#  ['m30978', 'm47979'],
#  ['m30978', 'm30614'],
#  ['m30978', 'm22176'],
#  ['m30978', 'm44505'],
#  ['m30978', 'm45549'],
#  ['m30978', 'm30752'],
#  ['m30978', 'm27844'],
#  ['m30978', 'm45342'],
#  ['m30978', 'm45605'],
#  ['m30978', 'm47727'],
#  ['m30978', 'm45950'],
#  ['m30978', 'm43457'],
#  ['m30978', 'm45337'],
#  ['m30978', 'm48478'],
#  ['m30978', 'm46088'],
#  ['m30978', 'm45450'],
#  ['m30978', 'm47821'],
#  ['m30978', 'm45126'],
#  ['m30978', 'm46018'],
#  ['m30978', 'm47403'],
#  ['m30978', 'm29814'],
#  ['m30978', 'm47847'],
#  ['m30978', 'm44326'],
#  ['m30978', 'm42646'],
#  ['m30978', 'm24572'],
#  ['m30978', 'm25578'],
#  ['m30978', 'm47657'],
#  ['m30978', 'm44411'],
#  ['m30978', 'm26099'],
#  ['m30978', 'm20084'],
#  ['m30978', 'm45276'],
#  ['m30978', 'm45286'],
#  ['m30978', 'm23916'],
#  ['m30978', 'm47594'],
#  ['m30978', 'm26306'],
#  ['m30978', 'm45466'],
#  ['m30978', 'm47017'],
#  ['m30978', 'm16257'],
#  ['m30978', 'm28789'],
#  ['m30978', 'm47591'],
#  ['m30978', 'm10157'],
#  ['m30978', 'm3824'],
#  ['m30978', 'm30058'],
#  ['m30978', 'm26579'],
#  ['m30978', 'm45216'],
#  ['m30978', 'm30227'],
#  ['m30978', 'm45489'],
#  ['m30978', 'm46863'],
#  ['m30978', 'm24408'],
#  ['m30978', 'm47456'],
#  ['m30978', 'm49354'],
#  ['m30978', 'm29464'],
#  ['m30978', 'm48582'],
#  ['m30978', 'm27361'],
#  ['m30978', 'm43516'],
#  ['m30978', 'm44032'],
#  ['m30978', 'm19304'],
#  ['m30978', 'm42039'],
#  ['m30978', 'm45366'],
#  ['m30978', 'm45518'],
#  ['m30978', 'm46219'],
#  ['m30978', 'm46375'],
#  ['m30978', 'm18345'],
#  ['m30978', 'm45439'],
#  ['m30978', 'm28271'],
#  ['m30978', 'm28583'],
#  ['m30978', 'm45651'],
#  ['m30978', 'm24230'],
#  ['m30978', 'm21436'],
#  ['m30978', 'm46969'],
#  ['m30978', 'm47469'],
#  ['m30978', 'm46504'],
#  ['m30978', 'm15468'],
#  ['m30978', 'm43409'],
#  ['m30978', 'm45888'],
#  ['m30978', 'm19021'],
#  ['m30978', 'm21752'],
#  ['m3967', 'm6371'],
#  ['m6130', 'm4696'],
#  ['m6130', 'm4342'],
#  ['m6130', 'm4696'],
#  ['m6130', 'm4342'],
#  ['m4924', 'm134'],
#  ['m6130', 'm4696'],
#  ['m6130', 'm4342'],
#  ['m3967', 'm6371'],
#  ['m15230', 'm7912'],
#  ['m21347', 'm23516'],
#  ['m21347', 'm18082'],
#  ['m21347', 'm19896'],
#  ['m21347', 'm8009'],
#  ['m21347', 'm18222'],
#  ['m21347', 'm12029'],
#  ['m21347', 'm18920'],
#  ['m21347', 'm22904'],
#  ['m14467', 'm8051'],
#  ['m14467', 'm32066'],
#  ['m12029', 'm28826'],
#  ['m12029', 'm23197'],
#  ['m12029', 'm8111'],
#  ['m12029', 'm8571'],
#  ['m12029', 'm10825'],
#  ['m12029', 'm12111'],
#  ['m17013', 'm8145'],
#  ['m17013', 'm8254'],
#  ['m17013', 'm12071'],
#  ['m8145', 'm8254'],
#  ['m8546', 'm10402'],
#  ['m26860', 'm17642'],
#  ['m26860', 'm10951'],
#  ['m26860', 'm8568'],
#  ['m26860', 'm23607'],
#  ['m26860', 'm26918'],
#  ['m26860', 'm25157'],
#  ['m26860', 'm17894'],
#  ['m26860', 'm17264'],
#  ['m26860', 'm8672'],
#  ['m26860', 'm8879'],
#  ['m26860', 'm26756'],
#  ['m26860', 'm25419'],
#  ['m26860', 'm30162'],
#  ['m12029', 'm28826'],
#  ['m12029', 'm23197'],
#  ['m12029', 'm8111'],
#  ['m12029', 'm8571'],
#  ['m12029', 'm10825'],
#  ['m12029', 'm12111'],
#  ['m26860', 'm10951'],
#  ['m26860', 'm17642'],
#  ['m26860', 'm8568'],
#  ['m26860', 'm23607'],
#  ['m26860', 'm26918'],
#  ['m26860', 'm25157'],
#  ['m26860', 'm17894'],
#  ['m26860', 'm17264'],
#  ['m26860', 'm8672'],
#  ['m26860', 'm8879'],
#  ['m26860', 'm26756'],
#  ['m26860', 'm25419'],
#  ['m26860', 'm30162'],
#  ['m26141', 'm8767'],
#  ['m8810', 'm12824'],
#  ['m8810', 'm13773'],
#  ['m8818', 'm14842'],
#  ['m26860', 'm17642'],
#  ['m26860', 'm10951'],
#  ['m26860', 'm8568'],
#  ['m26860', 'm23607'],
#  ['m26860', 'm26918'],
#  ['m26860', 'm25157'],
#  ['m26860', 'm17894'],
#  ['m26860', 'm17264'],
#  ['m26860', 'm8672'],
#  ['m26860', 'm8879'],
#  ['m26860', 'm26756'],
#  ['m26860', 'm25419'],
#  ['m26860', 'm30162'],
#  ['m10027', 'm9087'],
#  ['m9419', 'm14246'],
#  ['m10027', 'm9087'],
#  ['m10027', 'm10825'],
#  ['m30978', 'm48358'],
#  ['m30978', 'm46590'],
#  ['m30978', 'm44583'],
#  ['m30978', 'm45640'],
#  ['m30978', 'm21870'],
#  ['m30978', 'm28835'],
#  ['m30978', 'm13010'],
#  ['m30978', 'm24822'],
#  ['m30978', 'm15722'],
#  ['m30978', 'm45731'],
#  ['m30978', 'm36295'],
#  ['m30978', 'm23669'],
#  ['m30978', 'm45404'],
#  ['m30978', 'm18373'],
#  ['m30978', 'm43299'],
#  ['m30978', 'm30321'],
#  ['m30978', 'm23999'],
#  ['m30978', 'm30611'],
#  ['m30978', 'm45740'],
#  ['m30978', 'm47616'],
#  ['m30978', 'm30001'],
#  ['m30978', 'm44835'],
#  ['m30978', 'm30937'],
#  ['m30978', 'm48523'],
#  ['m30978', 'm16724'],
#  ['m30978', 'm47986'],
#  ['m30978', 'm40127'],
#  ['m30978', 'm49631'],
#  ['m30978', 'm40096'],
#  ['m30978', 'm43102'],
#  ['m30978', 'm45538'],
#  ['m30978', 'm45610'],
#  ['m30978', 'm47949'],
#  ['m30978', 'm46860'],
#  ['m30978', 'm47792'],
#  ['m30978', 'm23228'],
#  ['m30978', 'm27873'],
#  ['m30978', 'm44515'],
#  ['m30978', 'm25722'],
#  ['m30978', 'm46110'],
#  ['m30978', 'm44929'],
#  ['m30978', 'm45456'],
#  ['m30978', 'm45946'],
#  ['m30978', 'm47492'],
#  ['m30978', 'm39870'],
#  ['m30978', 'm45696'],
#  ['m30978', 'm47979'],
#  ['m30978', 'm30614'],
#  ['m30978', 'm22176'],
#  ['m30978', 'm44505'],
#  ['m30978', 'm45549'],
#  ['m30978', 'm30752'],
#  ['m30978', 'm27844'],
#  ['m30978', 'm45342'],
#  ['m30978', 'm45605'],
#  ['m30978', 'm47727'],
#  ['m30978', 'm45950'],
#  ['m30978', 'm43457'],
#  ['m30978', 'm45337'],
#  ['m30978', 'm48478'],
#  ['m30978', 'm46088'],
#  ['m30978', 'm45450'],
#  ['m30978', 'm47821'],
#  ['m30978', 'm45126'],
#  ['m30978', 'm46018'],
#  ['m30978', 'm47403'],
#  ['m30978', 'm29814'],
#  ['m30978', 'm47847'],
#  ['m30978', 'm44326'],
#  ['m30978', 'm42646'],
#  ['m30978', 'm24572'],
#  ['m30978', 'm25578'],
#  ['m30978', 'm47657'],
#  ['m30978', 'm44411'],
#  ['m30978', 'm26099'],
#  ['m30978', 'm20084'],
#  ['m30978', 'm45276'],
#  ['m30978', 'm45286'],
#  ['m30978', 'm23916'],
#  ['m30978', 'm47594'],
#  ['m30978', 'm26306'],
#  ['m30978', 'm45466'],
#  ['m30978', 'm47017'],
#  ['m30978', 'm16257'],
#  ['m30978', 'm28789'],
#  ['m30978', 'm47591'],
#  ['m30978', 'm10157'],
#  ['m30978', 'm3824'],
#  ['m30978', 'm30058'],
#  ['m30978', 'm26579'],
#  ['m30978', 'm45216'],
#  ['m30978', 'm30227'],
#  ['m30978', 'm45489'],
#  ['m30978', 'm46863'],
#  ['m30978', 'm24408'],
#  ['m30978', 'm47456'],
#  ['m30978', 'm49354'],
#  ['m30978', 'm29464'],
#  ['m30978', 'm48582'],
#  ['m30978', 'm27361'],
#  ['m30978', 'm43516'],
#  ['m30978', 'm44032'],
#  ['m30978', 'm19304'],
#  ['m30978', 'm42039'],
#  ['m30978', 'm45366'],
#  ['m30978', 'm45518'],
#  ['m30978', 'm46219'],
#  ['m30978', 'm46375'],
#  ['m30978', 'm18345'],
#  ['m30978', 'm45439'],
#  ['m30978', 'm28271'],
#  ['m30978', 'm28583'],
#  ['m30978', 'm45651'],
#  ['m30978', 'm24230'],
#  ['m30978', 'm21436'],
#  ['m30978', 'm46969'],
#  ['m30978', 'm47469'],
#  ['m30978', 'm46504'],
#  ['m30978', 'm15468'],
#  ['m30978', 'm43409'],
#  ['m30978', 'm45888'],
#  ['m30978', 'm19021'],
#  ['m30978', 'm21752'],
#  ['m13011', 'm8546'],
#  ['m13011', 'm10402'],
#  ['m27867', 'm10428'],
#  ['m12029', 'm10027'],
#  ['m12029', 'm28826'],
#  ['m12029', 'm23197'],
#  ['m12029', 'm8111'],
#  ['m12029', 'm8571'],
#  ['m12029', 'm10825'],
#  ['m12029', 'm12111'],
#  ['m12029', 'm13478'],
#  ['m26860', 'm17642'],
#  ['m26860', 'm10951'],
#  ['m26860', 'm8568'],
#  ['m26860', 'm23607'],
#  ['m26860', 'm26918'],
#  ['m26860', 'm25157'],
#  ['m26860', 'm17894'],
#  ['m26860', 'm17264'],
#  ['m26860', 'm8672'],
#  ['m26860', 'm8879'],
#  ['m26860', 'm26756'],
#  ['m26860', 'm25419'],
#  ['m26860', 'm30162'],
#  ['m10998', 'm13478'],
#  ['m11454', 'm12818'],
#  ['m32066', 'm11606'],
#  ['m20260', 'm22754'],
#  ['m20260', 'm11647'],
#  ['m20260', 'm20002'],
#  ['m12029', 'm8111'],
#  ['m12029', 'm28826'],
#  ['m12029', 'm23197'],
#  ['m12029', 'm8009'],
#  ['m12029', 'm8571'],
#  ['m12029', 'm10825'],
#  ['m12029', 'm12111'],
#  ['m8145', 'm12071'],
#  ['m21347', 'm12029'],
#  ['m21347', 'm13433'],
#  ['m21347', 'm20902'],
#  ['m21347', 'm23197'],
#  ['m21347', 'm8111'],
#  ['m21347', 'm28826'],
#  ['m21347', 'm8571'],
#  ['m21347', 'm10825'],
#  ['m21347', 'm12111'],
#  ['m12400', 'm33007'],
#  ['m11454', 'm12818'],
#  ['m8810', 'm12824'],
#  ['m8810', 'm13773'],
#  ['m12999', 'm35265'],
#  ['m30978', 'm48358'],
#  ['m30978', 'm46590'],
#  ['m30978', 'm44583'],
#  ['m30978', 'm45640'],
#  ['m30978', 'm21870'],
#  ['m30978', 'm28835'],
#  ['m30978', 'm13010'],
#  ['m30978', 'm24822'],
#  ['m30978', 'm15722'],
#  ['m30978', 'm45731'],
#  ['m30978', 'm36295'],
#  ['m30978', 'm23669'],
#  ['m30978', 'm45404'],
#  ['m30978', 'm18373'],
#  ['m30978', 'm43299'],
#  ['m30978', 'm30321'],
#  ['m30978', 'm23999'],
#  ['m30978', 'm30611'],
#  ['m30978', 'm45740'],
#  ['m30978', 'm47616'],
#  ['m30978', 'm30001'],
#  ['m30978', 'm44835'],
#  ['m30978', 'm30937'],
#  ['m30978', 'm48523'],
#  ['m30978', 'm16724'],
#  ['m30978', 'm47986'],
#  ['m30978', 'm40127'],
#  ['m30978', 'm49631'],
#  ['m30978', 'm40096'],
#  ['m30978', 'm43102'],
#  ['m30978', 'm45538'],
#  ['m30978', 'm45610'],
#  ['m30978', 'm47949'],
#  ['m30978', 'm46860'],
#  ['m30978', 'm47792'],
#  ['m30978', 'm23228'],
#  ['m30978', 'm27873'],
#  ['m30978', 'm44515'],
#  ['m30978', 'm25722'],
#  ['m30978', 'm46110'],
#  ['m30978', 'm44929'],
#  ['m30978', 'm45456'],
#  ['m30978', 'm45946'],
#  ['m30978', 'm47492'],
#  ['m30978', 'm39870'],
#  ['m30978', 'm45696'],
#  ['m30978', 'm47979'],
#  ['m30978', 'm30614'],
#  ['m30978', 'm22176'],
#  ['m30978', 'm44505'],
#  ['m30978', 'm45549'],
#  ['m30978', 'm30752'],
#  ['m30978', 'm27844'],
#  ['m30978', 'm45342'],
#  ['m30978', 'm45605'],
#  ['m30978', 'm47727'],
#  ['m30978', 'm45950'],
#  ['m30978', 'm43457'],
#  ['m30978', 'm45337'],
#  ['m30978', 'm48478'],
#  ['m30978', 'm46088'],
#  ['m30978', 'm45450'],
#  ['m30978', 'm47821'],
#  ['m30978', 'm45126'],
#  ['m30978', 'm46018'],
#  ['m30978', 'm47403'],
#  ['m30978', 'm29814'],
#  ['m30978', 'm47847'],
#  ['m30978', 'm44326'],
#  ['m30978', 'm42646'],
#  ['m30978', 'm24572'],
#  ['m30978', 'm25578'],
#  ['m30978', 'm47657'],
#  ['m30978', 'm44411'],
#  ['m30978', 'm26099'],
#  ['m30978', 'm20084'],
#  ['m30978', 'm45276'],
#  ['m30978', 'm45286'],
#  ['m30978', 'm23916'],
#  ['m30978', 'm47594'],
#  ['m30978', 'm26306'],
#  ['m30978', 'm45466'],
#  ['m30978', 'm47017'],
#  ['m30978', 'm16257'],
#  ['m30978', 'm28789'],
#  ['m30978', 'm47591'],
#  ['m30978', 'm10157'],
#  ['m30978', 'm3824'],
#  ['m30978', 'm30058'],
#  ['m30978', 'm26579'],
#  ['m30978', 'm45216'],
#  ['m30978', 'm30227'],
#  ['m30978', 'm45489'],
#  ['m30978', 'm46863'],
#  ['m30978', 'm24408'],
#  ['m30978', 'm47456'],
#  ['m30978', 'm49354'],
#  ['m30978', 'm29464'],
#  ['m30978', 'm48582'],
#  ['m30978', 'm27361'],
#  ['m30978', 'm43516'],
#  ['m30978', 'm44032'],
#  ['m30978', 'm19304'],
#  ['m30978', 'm42039'],
#  ['m30978', 'm45366'],
#  ['m30978', 'm45518'],
#  ['m30978', 'm46219'],
#  ['m30978', 'm46375'],
#  ['m30978', 'm18345'],
#  ['m30978', 'm45439'],
#  ['m30978', 'm28271'],
#  ['m30978', 'm28583'],
#  ['m30978', 'm45651'],
#  ['m30978', 'm24230'],
#  ['m30978', 'm21436'],
#  ['m30978', 'm46969'],
#  ['m30978', 'm47469'],
#  ['m30978', 'm46504'],
#  ['m30978', 'm15468'],
#  ['m30978', 'm43409'],
#  ['m30978', 'm45888'],
#  ['m30978', 'm19021'],
#  ['m30978', 'm21752'],
#  ['m13011', 'm10402'],
#  ['m13433', 'm12111'],
#  ['m13433', 'm21347'],
#  ['m10998', 'm13478'],
#  ['m10998', 'm10825'],
#  ['m8810', 'm12824'],
#  ['m8810', 'm13773'],
#  ['m9419', 'm14246'],
#  ['m14467', 'm8051'],
#  ['m14489', 'm19809'],
#  ['m15088', 'm14579'],
#  ['m8818', 'm14842'],
#  ['m28118', 'm14864'],
#  ['m43624', 'm15008'],
#  ['m15088', 'm14579'],
#  ['m15230', 'm7912'],
#  ['m30978', 'm48358'],
#  ['m30978', 'm46590'],
#  ['m30978', 'm44583'],
#  ['m30978', 'm45640'],
#  ['m30978', 'm21870'],
#  ['m30978', 'm28835'],
#  ['m30978', 'm13010'],
#  ['m30978', 'm24822'],
#  ['m30978', 'm15722'],
#  ['m30978', 'm45731'],
#  ['m30978', 'm36295'],
#  ['m30978', 'm23669'],
#  ['m30978', 'm45404'],
#  ['m30978', 'm18373'],
#  ['m30978', 'm43299'],
#  ['m30978', 'm30321'],
#  ['m30978', 'm23999'],
#  ['m30978', 'm30611'],
#  ['m30978', 'm45740'],
#  ['m30978', 'm47616'],
#  ['m30978', 'm30001'],
#  ['m30978', 'm44835'],
#  ['m30978', 'm30937'],
#  ['m30978', 'm48523'],
#  ['m30978', 'm16724'],
#  ['m30978', 'm47986'],
#  ['m30978', 'm40127'],
#  ['m30978', 'm49631'],
#  ['m30978', 'm40096'],
#  ['m30978', 'm43102'],
#  ['m30978', 'm45538'],
#  ['m30978', 'm45610'],
#  ['m30978', 'm47949'],
#  ['m30978', 'm46860'],
#  ['m30978', 'm47792'],
#  ['m30978', 'm23228'],
#  ['m30978', 'm27873'],
#  ['m30978', 'm44515'],
#  ['m30978', 'm25722'],
#  ['m30978', 'm46110'],
#  ['m30978', 'm44929'],
#  ['m30978', 'm45456'],
#  ['m30978', 'm45946'],
#  ['m30978', 'm47492'],
#  ['m30978', 'm39870'],
#  ['m30978', 'm45696'],
#  ['m30978', 'm47979'],
#  ['m30978', 'm30614'],
#  ['m30978', 'm22176'],
#  ['m30978', 'm44505'],
#  ['m30978', 'm45549'],
#  ['m30978', 'm30752'],
#  ['m30978', 'm27844'],
#  ['m30978', 'm45342'],
#  ['m30978', 'm45605'],
#  ['m30978', 'm47727'],
#  ['m30978', 'm45950'],
#  ['m30978', 'm43457'],
#  ['m30978', 'm45337'],
#  ['m30978', 'm48478'],
#  ['m30978', 'm46088'],
#  ['m30978', 'm45450'],
#  ['m30978', 'm47821'],
#  ['m30978', 'm45126'],
#  ['m30978', 'm46018'],
#  ['m30978', 'm47403'],
#  ['m30978', 'm29814'],
#  ['m30978', 'm47847'],
#  ['m30978', 'm44326'],
#  ['m30978', 'm42646'],
#  ['m30978', 'm24572'],
#  ['m30978', 'm25578'],
#  ['m30978', 'm47657'],
#  ['m30978', 'm44411'],
#  ['m30978', 'm26099'],
#  ['m30978', 'm20084'],
#  ['m30978', 'm45276'],
#  ['m30978', 'm45286'],
#  ['m30978', 'm23916'],
#  ['m30978', 'm47594'],
#  ['m30978', 'm26306'],
#  ['m30978', 'm45466'],
#  ['m30978', 'm47017'],
#  ['m30978', 'm16257'],
#  ['m30978', 'm28789'],
#  ['m30978', 'm47591'],
#  ['m30978', 'm10157'],
#  ['m30978', 'm3824'],
#  ['m30978', 'm30058'],
#  ['m30978', 'm26579'],
#  ['m30978', 'm45216'],
#  ['m30978', 'm30227'],
#  ['m30978', 'm45489'],
#  ['m30978', 'm46863'],
#  ['m30978', 'm24408'],
#  ['m30978', 'm47456'],
#  ['m30978', 'm49354'],
#  ['m30978', 'm29464'],
#  ['m30978', 'm48582'],
#  ['m30978', 'm27361'],
#  ['m30978', 'm43516'],
#  ['m30978', 'm44032'],
#  ['m30978', 'm19304'],
#  ['m30978', 'm42039'],
#  ['m30978', 'm45366'],
#  ['m30978', 'm45518'],
#  ['m30978', 'm46219'],
#  ['m30978', 'm46375'],
#  ['m30978', 'm18345'],
#  ['m30978', 'm45439'],
#  ['m30978', 'm28271'],
#  ['m30978', 'm28583'],
#  ['m30978', 'm45651'],
#  ['m30978', 'm24230'],
#  ['m30978', 'm21436'],
#  ['m30978', 'm46969'],
#  ['m30978', 'm47469'],
#  ['m30978', 'm46504'],
#  ['m30978', 'm15468'],
#  ['m30978', 'm43409'],
#  ['m30978', 'm45888'],
#  ['m30978', 'm19021'],
#  ['m30978', 'm21752'],
#  ['m17720', 'm15555'],
#  ['m20809', 'm15619'],
#  ['m20809', 'm25201'],
#  ['m30978', 'm48358'],
#  ['m30978', 'm46590'],
#  ['m30978', 'm44583'],
#  ['m30978', 'm45640'],
#  ['m30978', 'm21870'],
#  ['m30978', 'm28835'],
#  ['m30978', 'm13010'],
#  ['m30978', 'm24822'],
#  ['m30978', 'm15722'],
#  ['m30978', 'm45731'],
#  ['m30978', 'm36295'],
#  ['m30978', 'm23669'],
#  ['m30978', 'm45404'],
#  ['m30978', 'm18373'],
#  ['m30978', 'm43299'],
#  ['m30978', 'm30321'],
#  ['m30978', 'm23999'],
#  ['m30978', 'm30611'],
#  ['m30978', 'm45740'],
#  ['m30978', 'm47616'],
#  ['m30978', 'm30001'],
#  ['m30978', 'm44835'],
#  ['m30978', 'm30937'],
#  ['m30978', 'm48523'],
#  ['m30978', 'm16724'],
#  ['m30978', 'm47986'],
#  ['m30978', 'm40127'],
#  ['m30978', 'm49631'],
#  ['m30978', 'm40096'],
#  ['m30978', 'm43102'],
#  ['m30978', 'm45538'],
#  ['m30978', 'm45610'],
#  ['m30978', 'm47949'],
#  ['m30978', 'm46860'],
#  ['m30978', 'm47792'],
#  ['m30978', 'm23228'],
#  ['m30978', 'm27873'],
#  ['m30978', 'm44515'],
#  ['m30978', 'm25722'],
#  ['m30978', 'm46110'],
#  ['m30978', 'm44929'],
#  ['m30978', 'm45456'],
#  ['m30978', 'm45946'],
#  ['m30978', 'm47492'],
#  ['m30978', 'm39870'],
#  ['m30978', 'm45696'],
#  ['m30978', 'm47979'],
#  ['m30978', 'm30614'],
#  ['m30978', 'm22176'],
#  ['m30978', 'm44505'],
#  ['m30978', 'm45549'],
#  ['m30978', 'm30752'],
#  ['m30978', 'm27844'],
#  ['m30978', 'm45342'],
#  ['m30978', 'm45605'],
#  ['m30978', 'm47727'],
#  ['m30978', 'm45950'],
#  ['m30978', 'm43457'],
#  ['m30978', 'm45337'],
#  ['m30978', 'm48478'],
#  ['m30978', 'm46088'],
#  ['m30978', 'm45450'],
#  ['m30978', 'm47821'],
#  ['m30978', 'm45126'],
#  ['m30978', 'm46018'],
#  ['m30978', 'm47403'],
#  ['m30978', 'm29814'],
#  ['m30978', 'm47847'],
#  ['m30978', 'm44326'],
#  ['m30978', 'm42646'],
#  ['m30978', 'm24572'],
#  ['m30978', 'm25578'],
#  ['m30978', 'm47657'],
#  ['m30978', 'm44411'],
#  ['m30978', 'm26099'],
#  ['m30978', 'm20084'],
#  ['m30978', 'm45276'],
#  ['m30978', 'm45286'],
#  ['m30978', 'm23916'],
#  ['m30978', 'm47594'],
#  ['m30978', 'm26306'],
#  ['m30978', 'm45466'],
#  ['m30978', 'm47017'],
#  ['m30978', 'm16257'],
#  ['m30978', 'm28789'],
#  ['m30978', 'm47591'],
#  ['m30978', 'm10157'],
#  ['m30978', 'm3824'],
#  ['m30978', 'm30058'],
#  ['m30978', 'm26579'],
#  ['m30978', 'm45216'],
#  ['m30978', 'm30227'],
#  ['m30978', 'm45489'],
#  ['m30978', 'm46863'],
#  ['m30978', 'm24408'],
#  ['m30978', 'm47456'],
#  ['m30978', 'm49354'],
#  ['m30978', 'm29464'],
#  ['m30978', 'm48582'],
#  ['m30978', 'm27361'],
#  ['m30978', 'm43516'],
#  ['m30978', 'm44032'],
#  ['m30978', 'm19304'],
#  ['m30978', 'm42039'],
#  ['m30978', 'm45366'],
#  ['m30978', 'm45518'],
#  ['m30978', 'm46219'],
#  ['m30978', 'm46375'],
#  ['m30978', 'm18345'],
#  ['m30978', 'm45439'],
#  ['m30978', 'm28271'],
#  ['m30978', 'm28583'],
#  ['m30978', 'm45651'],
#  ['m30978', 'm24230'],
#  ['m30978', 'm21436'],
#  ['m30978', 'm46969'],
#  ['m30978', 'm47469'],
#  ['m30978', 'm46504'],
#  ['m30978', 'm15468'],
#  ['m30978', 'm43409'],
#  ['m30978', 'm45888'],
#  ['m30978', 'm19021'],
#  ['m30978', 'm21752'],
#  ['m25169', 'm16060'],
#  ['m25341', 'm16241'],
#  ['m30978', 'm48358'],
#  ['m30978', 'm46590'],
#  ['m30978', 'm44583'],
#  ['m30978', 'm45640'],
#  ['m30978', 'm21870'],
#  ['m30978', 'm28835'],
#  ['m30978', 'm13010'],
#  ['m30978', 'm24822'],
#  ['m30978', 'm15722'],
#  ['m30978', 'm45731'],
#  ['m30978', 'm36295'],
#  ['m30978', 'm23669'],
#  ['m30978', 'm45404'],
#  ['m30978', 'm18373'],
#  ['m30978', 'm43299'],
#  ['m30978', 'm30321'],
#  ['m30978', 'm23999'],
#  ['m30978', 'm30611'],
#  ['m30978', 'm45740'],
#  ['m30978', 'm47616'],
#  ['m30978', 'm30001'],
#  ['m30978', 'm44835'],
#  ['m30978', 'm30937'],
#  ['m30978', 'm48523'],
#  ['m30978', 'm16724'],
#  ['m30978', 'm47986'],
#  ['m30978', 'm40127'],
#  ['m30978', 'm49631'],
#  ['m30978', 'm40096'],
#  ['m30978', 'm43102'],
#  ['m30978', 'm45538'],
#  ['m30978', 'm45610'],
#  ['m30978', 'm47949'],
#  ['m30978', 'm46860'],
#  ['m30978', 'm47792'],
#  ['m30978', 'm23228'],
#  ['m30978', 'm27873'],
#  ['m30978', 'm44515'],
#  ['m30978', 'm25722'],
#  ['m30978', 'm46110'],
#  ['m30978', 'm44929'],
#  ['m30978', 'm45456'],
#  ['m30978', 'm45946'],
#  ['m30978', 'm47492'],
#  ['m30978', 'm39870'],
#  ['m30978', 'm45696'],
#  ['m30978', 'm47979'],
#  ['m30978', 'm30614'],
#  ['m30978', 'm22176'],
#  ['m30978', 'm44505'],
#  ['m30978', 'm45549'],
#  ['m30978', 'm30752'],
#  ['m30978', 'm27844'],
#  ['m30978', 'm45342'],
#  ['m30978', 'm45605'],
#  ['m30978', 'm47727'],
#  ['m30978', 'm45950'],
#  ['m30978', 'm43457'],
#  ['m30978', 'm45337'],
#  ['m30978', 'm48478'],
#  ['m30978', 'm46088'],
#  ['m30978', 'm45450'],
#  ['m30978', 'm47821'],
#  ['m30978', 'm45126'],
#  ['m30978', 'm46018'],
#  ['m30978', 'm47403'],
#  ['m30978', 'm29814'],
#  ['m30978', 'm47847'],
#  ['m30978', 'm44326'],
#  ['m30978', 'm42646'],
#  ['m30978', 'm24572'],
#  ['m30978', 'm25578'],
#  ['m30978', 'm47657'],
#  ['m30978', 'm44411'],
#  ['m30978', 'm26099'],
#  ['m30978', 'm20084'],
#  ['m30978', 'm45276'],
#  ['m30978', 'm45286'],
#  ['m30978', 'm23916'],
#  ['m30978', 'm47594'],
#  ['m30978', 'm26306'],
#  ['m30978', 'm45466'],
#  ['m30978', 'm47017'],
#  ['m30978', 'm16257'],
#  ['m30978', 'm28789'],
#  ['m30978', 'm47591'],
#  ['m30978', 'm10157'],
#  ['m30978', 'm3824'],
#  ['m30978', 'm30058'],
#  ['m30978', 'm26579'],
#  ['m30978', 'm45216'],
#  ['m30978', 'm30227'],
#  ['m30978', 'm45489'],
#  ['m30978', 'm46863'],
#  ['m30978', 'm24408'],
#  ['m30978', 'm47456'],
#  ['m30978', 'm49354'],
#  ['m30978', 'm29464'],
#  ['m30978', 'm48582'],
#  ['m30978', 'm27361'],
#  ['m30978', 'm43516'],
#  ['m30978', 'm44032'],
#  ['m30978', 'm19304'],
#  ['m30978', 'm42039'],
#  ['m30978', 'm45366'],
#  ['m30978', 'm45518'],
#  ['m30978', 'm46219'],
#  ['m30978', 'm46375'],
#  ['m30978', 'm18345'],
#  ['m30978', 'm45439'],
#  ['m30978', 'm28271'],
#  ['m30978', 'm28583'],
#  ['m30978', 'm45651'],
#  ['m30978', 'm24230'],
#  ['m30978', 'm21436'],
#  ['m30978', 'm46969'],
#  ['m30978', 'm47469'],
#  ['m30978', 'm46504'],
#  ['m30978', 'm15468'],
#  ['m30978', 'm43409'],
#  ['m30978', 'm45888'],
#  ['m30978', 'm19021'],
#  ['m30978', 'm21752'],
#  ['m30064', 'm16588'],
#  ['m30064', 'm26542'],
#  ['m30978', 'm48358'],
#  ['m30978', 'm46590'],
#  ['m30978', 'm44583'],
#  ['m30978', 'm45640'],
#  ['m30978', 'm21870'],
#  ['m30978', 'm28835'],
#  ['m30978', 'm13010'],
#  ['m30978', 'm24822'],
#  ['m30978', 'm15722'],
#  ['m30978', 'm45731'],
#  ['m30978', 'm36295'],
#  ['m30978', 'm23669'],
#  ['m30978', 'm45404'],
#  ['m30978', 'm18373'],
#  ['m30978', 'm43299'],
#  ['m30978', 'm30321'],
#  ['m30978', 'm23999'],
#  ['m30978', 'm30611'],
#  ['m30978', 'm45740'],
#  ['m30978', 'm47616'],
#  ['m30978', 'm30001'],
#  ['m30978', 'm44835'],
#  ['m30978', 'm30937'],
#  ['m30978', 'm48523'],
#  ['m30978', 'm16724'],
#  ['m30978', 'm47986'],
#  ['m30978', 'm40127'],
#  ['m30978', 'm49631'],
#  ['m30978', 'm40096'],
#  ['m30978', 'm43102'],
#  ['m30978', 'm45538'],
#  ['m30978', 'm45610'],
#  ['m30978', 'm47949'],
#  ['m30978', 'm46860'],
#  ['m30978', 'm47792'],
#  ['m30978', 'm23228'],
#  ['m30978', 'm27873'],
#  ['m30978', 'm44515'],
#  ['m30978', 'm25722'],
#  ['m30978', 'm46110'],
#  ['m30978', 'm44929'],
#  ['m30978', 'm45456'],
#  ['m30978', 'm45946'],
#  ['m30978', 'm47492'],
#  ['m30978', 'm39870'],
#  ['m30978', 'm45696'],
#  ['m30978', 'm47979'],
#  ['m30978', 'm30614'],
#  ['m30978', 'm22176'],
#  ['m30978', 'm44505'],
#  ['m30978', 'm45549'],
#  ['m30978', 'm30752'],
#  ['m30978', 'm27844'],
#  ['m30978', 'm45342'],
#  ['m30978', 'm45605'],
#  ['m30978', 'm47727'],
#  ['m30978', 'm45950'],
#  ['m30978', 'm43457'],
#  ['m30978', 'm45337'],
#  ['m30978', 'm48478'],
#  ['m30978', 'm46088'],
#  ['m30978', 'm45450'],
#  ['m30978', 'm47821'],
#  ['m30978', 'm45126'],
#  ['m30978', 'm46018'],
#  ['m30978', 'm47403'],
#  ['m30978', 'm29814'],
#  ['m30978', 'm47847'],
#  ['m30978', 'm44326'],
#  ['m30978', 'm42646'],
#  ['m30978', 'm24572'],
#  ['m30978', 'm25578'],
#  ['m30978', 'm47657'],
#  ['m30978', 'm44411'],
#  ['m30978', 'm26099'],
#  ['m30978', 'm20084'],
#  ['m30978', 'm45276'],
#  ['m30978', 'm45286'],
#  ['m30978', 'm23916'],
#  ['m30978', 'm47594'],
#  ['m30978', 'm26306'],
#  ['m30978', 'm45466'],
#  ['m30978', 'm47017'],
#  ['m30978', 'm16257'],
#  ['m30978', 'm28789'],
#  ['m30978', 'm47591'],
#  ['m30978', 'm10157'],
#  ['m30978', 'm3824'],
#  ['m30978', 'm30058'],
#  ['m30978', 'm26579'],
#  ['m30978', 'm45216'],
#  ['m30978', 'm30227'],
#  ['m30978', 'm45489'],
#  ['m30978', 'm46863'],
#  ['m30978', 'm24408'],
#  ['m30978', 'm47456'],
#  ['m30978', 'm49354'],
#  ['m30978', 'm29464'],
#  ['m30978', 'm48582'],
#  ...]

# %%
candidate_pairs = []
for i in pairs1:
    if i not in candidate_pairs:
        candidate_pairs.append(i)

# %%
len(candidate_pairs)
# Out:
# 455

# %%
candidate_pairs
# Out:
# [['m4924', 'm134'],
#  ['m846', 'm813'],
#  ['m1163', 'm32722'],
#  ['m30978', 'm48358'],
#  ['m30978', 'm46590'],
#  ['m30978', 'm44583'],
#  ['m30978', 'm45640'],
#  ['m30978', 'm21870'],
#  ['m30978', 'm28835'],
#  ['m30978', 'm13010'],
#  ['m30978', 'm24822'],
#  ['m30978', 'm15722'],
#  ['m30978', 'm45731'],
#  ['m30978', 'm36295'],
#  ['m30978', 'm23669'],
#  ['m30978', 'm45404'],
#  ['m30978', 'm18373'],
#  ['m30978', 'm43299'],
#  ['m30978', 'm30321'],
#  ['m30978', 'm23999'],
#  ['m30978', 'm30611'],
#  ['m30978', 'm45740'],
#  ['m30978', 'm47616'],
#  ['m30978', 'm30001'],
#  ['m30978', 'm44835'],
#  ['m30978', 'm30937'],
#  ['m30978', 'm48523'],
#  ['m30978', 'm16724'],
#  ['m30978', 'm47986'],
#  ['m30978', 'm40127'],
#  ['m30978', 'm49631'],
#  ['m30978', 'm40096'],
#  ['m30978', 'm43102'],
#  ['m30978', 'm45538'],
#  ['m30978', 'm45610'],
#  ['m30978', 'm47949'],
#  ['m30978', 'm46860'],
#  ['m30978', 'm47792'],
#  ['m30978', 'm23228'],
#  ['m30978', 'm27873'],
#  ['m30978', 'm44515'],
#  ['m30978', 'm25722'],
#  ['m30978', 'm46110'],
#  ['m30978', 'm44929'],
#  ['m30978', 'm45456'],
#  ['m30978', 'm45946'],
#  ['m30978', 'm47492'],
#  ['m30978', 'm39870'],
#  ['m30978', 'm45696'],
#  ['m30978', 'm47979'],
#  ['m30978', 'm30614'],
#  ['m30978', 'm22176'],
#  ['m30978', 'm44505'],
#  ['m30978', 'm45549'],
#  ['m30978', 'm30752'],
#  ['m30978', 'm27844'],
#  ['m30978', 'm45342'],
#  ['m30978', 'm45605'],
#  ['m30978', 'm47727'],
#  ['m30978', 'm45950'],
#  ['m30978', 'm43457'],
#  ['m30978', 'm45337'],
#  ['m30978', 'm48478'],
#  ['m30978', 'm46088'],
#  ['m30978', 'm45450'],
#  ['m30978', 'm47821'],
#  ['m30978', 'm45126'],
#  ['m30978', 'm46018'],
#  ['m30978', 'm47403'],
#  ['m30978', 'm29814'],
#  ['m30978', 'm47847'],
#  ['m30978', 'm44326'],
#  ['m30978', 'm42646'],
#  ['m30978', 'm24572'],
#  ['m30978', 'm25578'],
#  ['m30978', 'm47657'],
#  ['m30978', 'm44411'],
#  ['m30978', 'm26099'],
#  ['m30978', 'm20084'],
#  ['m30978', 'm45276'],
#  ['m30978', 'm45286'],
#  ['m30978', 'm23916'],
#  ['m30978', 'm47594'],
#  ['m30978', 'm26306'],
#  ['m30978', 'm45466'],
#  ['m30978', 'm47017'],
#  ['m30978', 'm16257'],
#  ['m30978', 'm28789'],
#  ['m30978', 'm47591'],
#  ['m30978', 'm10157'],
#  ['m30978', 'm3824'],
#  ['m30978', 'm30058'],
#  ['m30978', 'm26579'],
#  ['m30978', 'm45216'],
#  ['m30978', 'm30227'],
#  ['m30978', 'm45489'],
#  ['m30978', 'm46863'],
#  ['m30978', 'm24408'],
#  ['m30978', 'm47456'],
#  ['m30978', 'm49354'],
#  ['m30978', 'm29464'],
#  ['m30978', 'm48582'],
#  ['m30978', 'm27361'],
#  ['m30978', 'm43516'],
#  ['m30978', 'm44032'],
#  ['m30978', 'm19304'],
#  ['m30978', 'm42039'],
#  ['m30978', 'm45366'],
#  ['m30978', 'm45518'],
#  ['m30978', 'm46219'],
#  ['m30978', 'm46375'],
#  ['m30978', 'm18345'],
#  ['m30978', 'm45439'],
#  ['m30978', 'm28271'],
#  ['m30978', 'm28583'],
#  ['m30978', 'm45651'],
#  ['m30978', 'm24230'],
#  ['m30978', 'm21436'],
#  ['m30978', 'm46969'],
#  ['m30978', 'm47469'],
#  ['m30978', 'm46504'],
#  ['m30978', 'm15468'],
#  ['m30978', 'm43409'],
#  ['m30978', 'm45888'],
#  ['m30978', 'm19021'],
#  ['m30978', 'm21752'],
#  ['m3967', 'm6371'],
#  ['m6130', 'm4696'],
#  ['m6130', 'm4342'],
#  ['m15230', 'm7912'],
#  ['m21347', 'm23516'],
#  ['m21347', 'm18082'],
#  ['m21347', 'm19896'],
#  ['m21347', 'm8009'],
#  ['m21347', 'm18222'],
#  ['m21347', 'm12029'],
#  ['m21347', 'm18920'],
#  ['m21347', 'm22904'],
#  ['m14467', 'm8051'],
#  ['m14467', 'm32066'],
#  ['m12029', 'm28826'],
#  ['m12029', 'm23197'],
#  ['m12029', 'm8111'],
#  ['m12029', 'm8571'],
#  ['m12029', 'm10825'],
#  ['m12029', 'm12111'],
#  ['m17013', 'm8145'],
#  ['m17013', 'm8254'],
#  ['m17013', 'm12071'],
#  ['m8145', 'm8254'],
#  ['m8546', 'm10402'],
#  ['m26860', 'm17642'],
#  ['m26860', 'm10951'],
#  ['m26860', 'm8568'],
#  ['m26860', 'm23607'],
#  ['m26860', 'm26918'],
#  ['m26860', 'm25157'],
#  ['m26860', 'm17894'],
#  ['m26860', 'm17264'],
#  ['m26860', 'm8672'],
#  ['m26860', 'm8879'],
#  ['m26860', 'm26756'],
#  ['m26860', 'm25419'],
#  ['m26860', 'm30162'],
#  ['m26141', 'm8767'],
#  ['m8810', 'm12824'],
#  ['m8810', 'm13773'],
#  ['m8818', 'm14842'],
#  ['m10027', 'm9087'],
#  ['m9419', 'm14246'],
#  ['m10027', 'm10825'],
#  ['m13011', 'm8546'],
#  ['m13011', 'm10402'],
#  ['m27867', 'm10428'],
#  ['m12029', 'm10027'],
#  ['m12029', 'm13478'],
#  ['m10998', 'm13478'],
#  ['m11454', 'm12818'],
#  ['m32066', 'm11606'],
#  ['m20260', 'm22754'],
#  ['m20260', 'm11647'],
#  ['m20260', 'm20002'],
#  ['m12029', 'm8009'],
#  ['m8145', 'm12071'],
#  ['m21347', 'm13433'],
#  ['m21347', 'm20902'],
#  ['m21347', 'm23197'],
#  ['m21347', 'm8111'],
#  ['m21347', 'm28826'],
#  ['m21347', 'm8571'],
#  ['m21347', 'm10825'],
#  ['m21347', 'm12111'],
#  ['m12400', 'm33007'],
#  ['m12999', 'm35265'],
#  ['m13433', 'm12111'],
#  ['m13433', 'm21347'],
#  ['m10998', 'm10825'],
#  ['m14489', 'm19809'],
#  ['m15088', 'm14579'],
#  ['m28118', 'm14864'],
#  ['m43624', 'm15008'],
#  ['m17720', 'm15555'],
#  ['m20809', 'm15619'],
#  ['m20809', 'm25201'],
#  ['m25169', 'm16060'],
#  ['m25341', 'm16241'],
#  ['m30064', 'm16588'],
#  ['m30064', 'm26542'],
#  ['m17036', 'm46508'],
#  ['m17097', 'm17076'],
#  ['m17097', 'm23516'],
#  ['m17312', 'm29665'],
#  ['m15555', 'm17720'],
#  ['m19809', 'm17971'],
#  ['m48179', 'm18007'],
#  ['m24664', 'm23261'],
#  ['m24664', 'm18129'],
#  ['m30025', 'm20661'],
#  ['m30025', 'm18144'],
#  ['m18225', 'm49783'],
#  ['m18271', 'm26515'],
#  ['m23221', 'm18354'],
#  ['m20764', 'm18489'],
#  ['m18920', 'm18515'],
#  ['m18920', 'm19068'],
#  ['m25701', 'm18889'],
#  ['m21347', 'm19068'],
#  ['m21347', 'm18515'],
#  ['m19515', 'm29374'],
#  ['m14489', 'm17971'],
#  ['m19868', 'm29802'],
#  ['m24892', 'm19962'],
#  ['m22747', 'm20260'],
#  ['m22747', 'm22754'],
#  ['m22747', 'm11647'],
#  ['m22747', 'm24285'],
#  ['m22747', 'm20002'],
#  ['m20008', 'm30738'],
#  ['m30281', 'm22148'],
#  ['m30281', 'm20124'],
#  ['m30281', 'm30649'],
#  ['m27385', 'm20303'],
#  ['m20450', 'm31572'],
#  ['m30994', 'm27164'],
#  ['m30994', 'm20457'],
#  ['m20661', 'm18144'],
#  ['m25357', 'm20710'],
#  ['m12111', 'm20902'],
#  ['m20942', 'm21729'],
#  ['m21024', 'm25008'],
#  ['m21347', 'm27164'],
#  ['m29826', 'm21663'],
#  ['m21860', 'm23073'],
#  ['m22486', 'm23516'],
#  ['m23710', 'm22493'],
#  ['m20260', 'm23593'],
#  ['m23200', 'm24923'],
#  ['m23221', 'm24026'],
#  ['m21347', 'm22486'],
#  ['m21347', 'm17097'],
#  ['m28432', 'm23554'],
#  ['m23593', 'm22754'],
#  ['m24285', 'm20002'],
#  ['m24664', 'm26435'],
#  ['m47900', 'm27029'],
#  ['m21347', 'm20457'],
#  ['m27247', 'm29281'],
#  ['m27667', 'm29315'],
#  ['m28213', 'm30124'],
#  ['m30860', 'm29000'],
#  ['m22148', 'm20124'],
#  ['m22148', 'm30649'],
#  ['m8051', 'm32066'],
#  ['m8051', 'm11606'],
#  ['m32232', 'm32525'],
#  ['m33686', 'm33650'],
#  ['m33650', 'm33686'],
#  ['m34296', 'm34300'],
#  ['m35042', 'm35014'],
#  ['m35402', 'm35390'],
#  ['m35394', 'm35444'],
#  ['m35447', 'm35427'],
#  ['m35427', 'm35447'],
#  ['m35427', 'm35469'],
#  ['m35427', 'm35489'],
#  ['m35447', 'm35469'],
#  ['m35447', 'm35489'],
#  ['m35786', 'm35790'],
#  ['m35847', 'm35981'],
#  ['m36020', 'm36016'],
#  ['m37016', 'm36980'],
#  ['m37016', 'm37559'],
#  ['m37016', 'm37195'],
#  ['m37559', 'm37016'],
#  ['m37559', 'm36980'],
#  ['m37559', 'm37195'],
#  ['m37086', 'm37559'],
#  ['m37086', 'm39184'],
#  ['m37086', 'm39400'],
#  ['m37086', 'm37532'],
#  ['m37086', 'm37030'],
#  ['m37086', 'm37499'],
#  ['m37086', 'm37195'],
#  ['m37086', 'm37217'],
#  ['m37086', 'm38736'],
#  ['m37086', 'm37369'],
#  ['m37086', 'm39380'],
#  ['m37086', 'm37670'],
#  ['m37086', 'm37390'],
#  ['m37803', 'm37140'],
#  ['m37803', 'm39184'],
#  ['m37803', 'm39380'],
#  ['m37086', 'm37016'],
#  ['m37086', 'm37311'],
#  ['m37086', 'm36980'],
#  ['m37086', 'm37639'],
#  ['m39400', 'm37311'],
#  ['m39400', 'm37195'],
#  ['m39400', 'm37639'],
#  ['m37351', 'm37378'],
#  ['m37378', 'm37351'],
#  ['m37559', 'm37030'],
#  ['m37559', 'm37217'],
#  ['m37885', 'm37857'],
#  ['m38310', 'm38026'],
#  ['m38310', 'm38702'],
#  ['m37086', 'm37803'],
#  ['m37086', 'm37140'],
#  ['m39608', 'm39626'],
#  ['m40025', 'm40078'],
#  ['m40253', 'm40266'],
#  ['m40329', 'm40495'],
#  ['m41300', 'm40433'],
#  ['m41116', 'm41048'],
#  ['m41070', 'm41203'],
#  ['m41250', 'm41272'],
#  ['m41436', 'm41474'],
#  ['m41658', 'm41577'],
#  ['m41651', 'm41760'],
#  ['m41651', 'm41927'],
#  ['m41845', 'm41654'],
#  ['m41845', 'm41772'],
#  ['m42352', 'm41995'],
#  ['m42352', 'm42682'],
#  ['m42352', 'm42567'],
#  ['m42352', 'm42167'],
#  ['m42352', 'm42767'],
#  ['m42352', 'm41724'],
#  ['m42019', 'm42154'],
#  ['m42352', 'm42901'],
#  ['m42352', 'm42997'],
#  ['m42461', 'm42289'],
#  ['m42461', 'm42589'],
#  ['m42606', 'm42670'],
#  ['m42606', 'm42368'],
#  ['m42488', 'm42464'],
#  ['m42517', 'm42609'],
#  ['m42879', 'm42982'],
#  ['m42879', 'm42747'],
#  ['m42784', 'm42958'],
#  ['m43037', 'm42808'],
#  ['m43077', 'm44092'],
#  ['m49477', 'm43487'],
#  ['m49477', 'm43085'],
#  ['m49477', 'm43099'],
#  ['m43205', 'm43100'],
#  ['m43205', 'm43086'],
#  ['m43205', 'm43488'],
#  ['m43205', 'm43825'],
#  ['m43267', 'm49647'],
#  ['m43280', 'm46063'],
#  ['m44146', 'm45035'],
#  ['m44441', 'm44609'],
#  ['m44596', 'm44608'],
#  ['m44837', 'm45007'],
#  ['m44968', 'm47109'],
#  ['m47018', 'm46980'],
#  ['m47018', 'm46041'],
#  ['m47018', 'm46680'],
#  ['m47018', 'm47062'],
#  ['m47018', 'm46993'],
#  ['m47018', 'm46768'],
#  ['m47018', 'm47234'],
#  ['m47018', 'm46743'],
#  ['m47018', 'm46378'],
#  ['m47018', 'm46887'],
#  ['m47018', 'm46956'],
#  ['m47018', 'm47209'],
#  ['m47018', 'm46516'],
#  ['m47018', 'm46876'],
#  ['m47018', 'm46529'],
#  ['m47018', 'm46826'],
#  ['m47018', 'm45259'],
#  ['m47018', 'm46756'],
#  ['m47018', 'm46925'],
#  ['m46030', 'm45261'],
#  ['m46030', 'm45659'],
#  ['m45423', 'm45515'],
#  ['m45658', 'm45493'],
#  ['m45658', 'm46029'],
#  ['m45515', 'm45423'],
#  ['m45649', 'm45623'],
#  ['m45649', 'm45634'],
#  ['m47018', 'm45800'],
#  ['m45991', 'm46378'],
#  ['m45991', 'm46529'],
#  ['m45991', 'm47018'],
#  ['m45991', 'm46887'],
#  ['m45991', 'm46768'],
#  ['m45991', 'm46826'],
#  ['m45991', 'm46756'],
#  ['m45991', 'm46980'],
#  ['m45991', 'm46956'],
#  ['m45991', 'm47209'],
#  ['m45991', 'm46680'],
#  ['m45991', 'm46743'],
#  ['m45991', 'm47062'],
#  ['m45991', 'm46516'],
#  ['m45991', 'm46925'],
#  ['m45261', 'm46030'],
#  ['m45261', 'm45659'],
#  ['m46063', 'm43280'],
#  ['m46168', 'm46405'],
#  ['m46254', 'm46595'],
#  ['m45991', 'm46041'],
#  ['m45991', 'm46993'],
#  ['m45991', 'm47234'],
#  ['m45991', 'm45800'],
#  ['m45991', 'm46876'],
#  ['m45991', 'm45259'],
#  ['m46390', 'm46404'],
#  ['m47147', 'm47534'],
#  ['m47147', 'm46543'],
#  ['m47147', 'm46782'],
#  ['m46783', 'm46544'],
#  ['m46898', 'm47260'],
#  ['m47583', 'm47515'],
#  ['m47684', 'm47935'],
#  ['m47698', 'm47936'],
#  ['m47706', 'm47819'],
#  ['m47917', 'm48291'],
#  ['m48010', 'm48021'],
#  ['m48326', 'm48092'],
#  ['m48507', 'm48171'],
#  ['m48721', 'm48706'],
#  ['m49124', 'm48707'],
#  ['m49124', 'm48722'],
#  ['m48801', 'm48804'],
#  ['m49123', 'm49059'],
#  ['m49492', 'm49478'],
#  ['m49860', 'm49901'],
#  ['m49902', 'm49861'],
#  ['m49998', 'm49864'],
#  ['m49954', 'm49941'],
#  ['m49864', 'm49998']]

# %% [markdown]
# # Topic Modeling

# %%
dictionary = corpora.Dictionary()

# %%
len(BoW_corpus)
# Out:
# 50000

# %%
#Build a list to store the tokenized words for each document
data_tokenized = []

# %%
#Clean the words in each docuemnt and then add them into the list
for i in data_content.index:  
    cleaned = clean(data_content[i])   
    data_tokenized.append(cleaned)

# %%
dictionary = corpora.Dictionary()

# %%
#We need to pass these tokenized words into dictionary.doc2bow() object
BoW_corpus = [
   dictionary.doc2bow(doc, allow_update=True) for doc in data_tokenized
]

# %%
#Sotre the Bow_corpus to the disk 
corpora.MmCorpus.serialize('E:\DataWeek5/BoW_corpus.mm',BoW_corpus)

# %%
#Apply the LDA algorithm
lda_model = LdaModel(corpus=BoW_corpus, id2word=dictionary, num_topics=10)

# %%
#Calculate the topic probality for each document
topic_prob =lda_model.get_document_topics(BoW_corpus )

# %%
len(topic_prob)
# Out:
# 50000

# %%
#Create a dic to store the topic for each dicument, we take the topic with the biggest probability as the topic of that document.
topic_document = {}
for i in enumerate(topic_prob):
    max = 0
    for j in i[1]:
        if j[1] > max:
            max = j[1]
            topic_document[i[0]] = j[0]

# %%
topic_document[0]
# Out:
# 4

# %%
topic_prob[0]
# Out:
# [(0, 0.35902563),
#  (1, 0.033763982),
#  (4, 0.39298293),
#  (7, 0.12081859),
#  (8, 0.09240359)]
